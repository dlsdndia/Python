# %% [markdown]
# # Web Crawling
# - 웹 스크래핑 : 웹 사이트 사에서 원하는 부분에 위치한 정보를 컴퓨터로 하여금 자동으로 추출하여 수집하는 기술
#     - 웹 크롤러가 가져오는 하나의 페이지가 있을 때, 추출하길 원하는 하목의 위치를 정해서 데이터를 가져오는 것
# - 웹 크롤링 : 자동화 봇(bot)인 웹 크롤러가 정해진 규칙에 따라 복수 개의 웹 페이지를 브라우징 하는 행위
#     - 링크를 따라 돌면서 원하는 페이지를 가져오는 과정
#
#
# - 크롤링 :
#     1. Web상에 존재하는 Contents를 수집하는 작업(프로그래밍으로 자동화 가능)
#     2. HTML 페이지를 가져와서, HTML/CSS 등을 파싱하고, 필요한 데이터만 추출하는 기법
#     3. Open API를 제공하는 서비스에 Open API를 호출해서, 받은 데이터 중 필요한 데이터만 추출하는 기법
#     4. Selenium 등 브라우저를 프로그래밍으로 조작해서, 필요한 데이터만 추출하는 기법

# %% [markdown]
# ## 강의 필기내용
#
# web : 컴퓨터가 통신을 이용한 자료공유
# - 컴퓨터간 통신 : computer network
# - 통신 형태 : 1:1 통신, 1:many 통신, N:M통신(다대다)
# - network 망 : LAN( local area network ), WAN( wide area network ), Internet
# - web이란 인터넷을 사용하는 서비스 형식
#
# HTTP( hyper text transfer protocol)
# - web service(web 브라우저를 이용하는 서비스)에 사용되는 protocol / 요청하고 응답할 때 사용 / 서버와 클라이언트와 통신을 할 수 있도록 한 전송규약
# - DNS(도메인 네임 서비스) ex) www.naver.com
# - 항상 통신이 되려면 환경에 맞는 protocal이 필요함
# - web에서 사용하는 언어 = HTML(hyper text markup language) -> HTTP 환경 프로토콜에서 작동하는 웹 언어
# - HTTP에서는 항상 HTML로 응답하고 요청한다.
# - HTML은 서버가 클라이언트에게 통신에 대한 결과를 보여줄 때 사용하는 웹 언어
#
# 크롤링 : HTML을 웹에서 가져오면(수집) HTML을 해석, 정보를 빼내는 것
#
# p397 ~ 400 참고.

# %% [markdown]
# ## webbrowser
#
# - webbrowser 모듈은 웹 기반 문서를 사용자에게 표시할 수 있는 고수준 인터페이스 제공

# %%
import webbrowser

# %%
url = 'www.naver.com'

webbrowser.open( url )
# Out:
# True

# %%
naver_search_url = 'https://search.naver.com/search.naver?query='
search_word = '파이썬'
url = naver_search_url + search_word

webbrowser.open( url )
# Out:
# True

# %%
google_url = 'www.google.com/#q='
search_word = '파이썬'
url = google_url + search_word

webbrowser.open( url )
# Out:
# True

# %% [markdown]
# ## 강의 메모
#
#
# **web client가 web severdp 요청하는 방식**
#
# - Get 방식 =  주소 표시줄에 모두표시 / 위에 구글 검색을 예로 구글 주소창에 (https://www.google.com/search?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&cad=h)이 다 나옴 / 대신 요청 내용이 다 나오기 때문에 보안에 약함
#
# - post 방식 = 주소 표시줄에 요청 내용이 가려짐, 보안에 강함

# %% [markdown]
# ## urllib
#
# - URL 작업을 위한 여러 모듈을 모은 패키지
# - URL을 열고 / 읽기 위한 urllib.request
# - URL 구문 분석을 위한  urllib.parse

# %%
import urllib.request

# %%
naver = urllib.request.urlopen( 'https://www.naver.com' )
naver.read()   # 요청에 대한 응답결과 내용 출력 (HTML코드 내용)
# Out:
# b'\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x8
# ...

# %%
naver = urllib.request.urlopen( 'https://www.naver.com' )
naver.read().decode( 'utf-8' )  # 제어문자들이 빠진 내용
# Out:
# '\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인
# ...

# %% [markdown]
# ## 강의 메모
#
# HTML file : web서버가 web클라이언트에게 제공하는 file
#
# - HTML : 웹 페이지의 구조를 결정한다
#
# - css( Cascade style sheet ) : 웹 펭지에 대한 효과를 적용한다.
#
# - JavaScript : 웹 페이지를 동적으로 동작하게 한다.
#
# -> 위에 3개를 통칭해서 Front-end 기술(요청자, client 담당 스크립 작성) / back-end(응답자, sever 담당)
# * meta태그는 /meta같이 끝 태그를 마지막에 붙이지 않는다  <meta 내용> 괄호 안에 들어감 / meta태그는 속성을 부여하는 것이기 때문에
# 안에 부여한다. meta태그는 charset을 기본으로 사용한다.
# * div태그는 공간분할 태그 (한칸 띄움)
# * attribute / id : tag에 유일성 보장 목적(다른 것과 구별), class : tag를 묶어주는 목적
# * a 태그 : 웹을 활성화시킨 하이퍼 태그임, 커서를 가져다 대면 다른 링크로 연결하는 것
#
# p.396 ~ 401

# %% [markdown]
# ## requests
#
# - HTTP 요청을 보내는 모듈
# - 서버에 요청해서 html을 받아 오는 것이 목적!

# %%
import requests

# %%
response = requests.get( 'https://www.naver.com' )
response.text
# Out:
# '\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인
# ...

# %%
response = requests.get( 'https://www.naver.com' )
response.status_code
# Out:
# 200

# %%
response.content  # (제어문자들이 다 포함된 것, 텍스트는 제어문자까지 안나옴)
# Out:
# b'\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x8
# ...

# %% [markdown]
# ## BeautifulSoup
#
# - HTML 태그를 파싱(parsing)해서 필요한 데이터만 추출하는 함수를 제공하는 라이브러리
#
# http://omz-software.com/pythonista/docs/ios/beautifulsoup_guide.html     -> # 가이드

# %%
from bs4 import BeautifulSoup

# %%
# test용 html 코드
html = '''
<html>
    <body>
        <div>
            <span>
                <a href=https://www.naver.com>naver</a>
                <a href=https://www.google.com>google</a>
                <a href=https://www.daum.com>daum</a>
            </span>
        </div>
    </body>  
</html>    
'''
# inline 형식의 공간분할 = <span>

# %%
#BeautifulSoup을 이용한 HTML 코드 파싱
soup = BeautifulSoup( html, 'lxml' )  # BeautifulSoup((파싱할 html이 담겨있는 변수), (paser의 종류))
soup
# Out:
# <html>
# <body>
# <div>
# <span>
# <a href="https://www.naver.com">naver</a>
# <a href="https://www.google.com">google</a>
# <a href="https://www.daum.com">daum</a>
# </span>
# </div>
# </body>
# </html>

# %%
soup.find( 'a' ) # .find = 검색, 'a'태그를 검색 해라, find()는 태그 중에 가장 먼저 찾은거 하나만 찾음!
# Out:
# <a href="https://www.naver.com">naver</a>

# %%
soup.find( 'a' ).get_text() # 검색된 태그 <a href="https://www.naver.com">naver</a>의  끝에 naver를 찾은 거(화면에 보이는 것)
                            #, 왜냐면 내가 원하는 데이터가 화면에 보이는 naver이기 때문에, 화면에는 naver만 보이고 왼쪽건 x
# Out:
# 'naver'

# %%
soup.find_all( 'a' )
# Out:
# [<a href="https://www.naver.com">naver</a>,
#  <a href="https://www.google.com">google</a>,
#  <a href="https://www.daum.com">daum</a>]

# %%
site_names = soup.find_all( 'a' )
for site_names in site_names:
    print( site_names.get_text() )
# Out:
# naver
# google
# daum

# %% [markdown]
# ### Web Scraping 절차 (위에 과정 정리)
#
# 1. 자료 추출을 원하는 web site에 요청을 보내서 응답(HTML)을 받는다.
#
# 2. 응답(HTML)받은 결과를 파싱한다. - BeautifulSoup
#
# 3. 파싱된 결과에서 원하는 데이터가 존재하는 태그를 검색한다.
#
# 4. 검색된 태그로 부터 데이터를 추출한다.

# %%
html = '''
<html>
    <head>
        <title>작품과 작가 모음</title>
    </head>
    <body>
        <h1>책 정보</h1>
        <p id= "book_title">토지</p> 
        <p id= "author">박경리</p>
        
        <p id= "book_title">태백산맥</p>
        <p id= "author">조정래</p>
        
        <p id= "book_title">감옥으로부터의 사색</p>
        <p id= "author">신영복</p>
    </body>
</html>    
'''
## p태그 안에 있는  id = "book_title"은  특성, 속성 / 토지는 콘텐츠(content)

# %%
soup2 = BeautifulSoup( html, 'lxml' )

# %%
soup2.title   # 웹브라우저 화면에 나오는게 아니고 타이틀이나 주쇼표시창에 나옴! / head 태그는 화면에 출력 안됨
# Out:
# <title>작품과 작가 모음</title>

# %%
soup2.body     # 화면에 출련되는 것
# Out:
# <body>
# <h1>책 정보</h1>
# <p id="book_title">토지</p>
# <p id="author">박경리</p>
# <p id="book_title">태백산맥</p>
# <p id="author">조정래</p>
# <p id="book_title">감옥으로부터의 사색</p>
# <p id="author">신영복</p>
# </body>

# %%
soup2.body.h1  #
# Out:
# <h1>책 정보</h1>

# %%
soup2.find( 'p', { 'id': 'book_title' } )
# Out:
# <p id="book_title">토지</p>

# %%
soup2.find( 'p', { 'id': 'author' } )
# Out:
# <p id="author">박경리</p>

# %%
soup2.find( 'p', { 'id': 'book_title' } )
# Out:
# <p id="book_title">토지</p>

# %%
soup2.find_all( 'p', { 'id': 'book_title' } )
# Out:
# [<p id="book_title">토지</p>,
#  <p id="book_title">태백산맥</p>,
#  <p id="book_title">감옥으로부터의 사색</p>]

# %%
soup2.find_all( 'p', { 'id': 'author' } )
# Out:
# [<p id="author">박경리</p>, <p id="author">조정래</p>, <p id="author">신영복</p>]

# %%
book_titles = soup2.find_all( 'p', { 'id': 'book_title' } )
authors = soup2.find_all( 'p', { 'id': 'author' } )

for book_title, author in zip(book_titles, authors):       # 길이가 같으니 zip으로 묶을 수 있음 / zip은 튜플로 내보냄
    print( book_title.get_text() + ' / ' + author.get_text() )
# Out:
# 토지 / 박경리
# 태백산맥 / 조정래
# 감옥으로부터의 사색 / 신영복

# %% [markdown]
# ## CSS style의 select()메서드

# %%
soup2.select( 'body h1' )
# Out:
# [<h1>책 정보</h1>]

# %%
soup2.select( 'body p' )
# Out:
# [<p id="book_title">토지</p>,
#  <p id="author">박경리</p>,
#  <p id="book_title">태백산맥</p>,
#  <p id="author">조정래</p>,
#  <p id="book_title">감옥으로부터의 사색</p>,
#  <p id="author">신영복</p>]

# %%
soup2.select( 'p' )
# Out:
# [<p id="book_title">토지</p>,
#  <p id="author">박경리</p>,
#  <p id="book_title">태백산맥</p>,
#  <p id="author">조정래</p>,
#  <p id="book_title">감옥으로부터의 사색</p>,
#  <p id="author">신영복</p>]

# %%
soup2.select( 'p#book_title' )    # '#'은 id에 대한 css style -> 'id'에 대한 것 찾기 / classsms '.'(온점)
# Out:
# [<p id="book_title">토지</p>,
#  <p id="book_title">태백산맥</p>,
#  <p id="book_title">감옥으로부터의 사색</p>]

# %%
soup2.select( 'p#author' )
# Out:
# [<p id="author">박경리</p>, <p id="author">조정래</p>, <p id="author">신영복</p>]

# %%
# %%writefile HTML_Basic2.html
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8">
#         <title>사이트 모음</title>
#     </head>
#     <body>
#         <p id="title"><b>자주 가는 사이트 모음</b></p>
#         <p id="contents"><b>이곳은 자주 가는 사이트를 모아둔 곳입니다.</p>
#         <a href="https://www.naver.com" class="potal">네이버</a><br>
#         <a href="https://www.google.com" class="search">구글</a><br>
#         <a href="https://www.daum.net" class="potal" id="daum">다음</a><br>
#         <a href="https://www.nl.go.kr" class="goverment" id="nl">국립중앙도서관</a>
#     </body>
# </html>
#
# #  <br> = 줄 바꿈 / <b> = 볼드, 글씨 굵게 하는 것
# Out:
# Writing HTML_Basic2.html

# %%
with open( 'HTML_Basic2.html', encoding = 'utf-8' ) as f:
    html = f.read()
    
soup3 = BeautifulSoup( html, 'lxml' )

# %%
soup3.select( 'a.potal' )    # soup3.select( '.potal' ) -> 유일성만 찾을 수 있으면 a태그 없어도 찾는 것 가능
# Out:
# [<a class="potal" href="https://www.naver.com">네이버</a>,
#  <a class="potal" href="https://www.daum.net" id="daum">다음</a>]

# %%
soup3.select( '#contents' )
# Out:
# [<p id="contents"><b>이곳은 자주 가는 사이트를 모아둔 곳입니다.</b></p>]

# %%
soup3.select( '#nl' )
# Out:
# [<a class="goverment" href="https://www.nl.go.kr" id="nl">국립중앙도서관</a>]

# %%
soup3.select( '#nl' )[ 0 ].get_text()
# Out:
# '국립중앙도서관'

# %% [markdown]
# ## 웹 스크래핑( Web Scraping )

# %% [markdown]
# ### 나라별 웹 사이트 순위
#
# https://www.alexa.com/topsites/countries/KR

# %%
url = 'https://www.alexa.com/topsites/countries/KR'

html_website_ranking = requests.get( url ).text
soup_website_ranking = BeautifulSoup( html_website_ranking, 'lxml' )

# %%
html_website_ranking
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n  <meta name="referer" content="origin-when-cross-origin"/>\n  <!-- Google Tag Manager -->\n  <script>\n  dataLayer = window.dataLayer || [];\n  dataLayer.push({\n    "lifecycle_stage": "prospect",\n  \t"logged-in":  false,\n    "customer": {\n      \n      "status": "prospect",\n      "highest_subscription": false\n    }\n  });\n  </script>\n  <!-- Page hiding snippet  -->\n  \n  <style>.async-hide { opacity: 0 !important} </style>\n  <script>(function(a,s,y,n,c,h,i,d,e){s.className+=\' \'+y;h.start=1*new Date;\n  h.end=i=function(){s.className=s.className.replace(RegExp(\' ?\'+y),\'\')};\n  (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;\n  })(window,document.documentElement,\'async-hide\',\'dataLayer\',4000,\n  {\'GTM-TKWQ4WC\':true});</script> \n  <!-- Modified Analytics tracking code with Optimize plugin -->\n      <script>\n      (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function()
# ...

# %%
soup_website_ranking
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="origin-when-cross-origin" name="referer"/>
# <!-- Google Tag Manager -->
# <script>
#   dataLayer = window.dataLayer || [];
#   dataLayer.push({
#     "lifecycle_stage": "prospect",
#   	"logged-in":  false,
#     "customer": {
#
#       "status": "prospect",
#       "highest_subscription": false
#     }
#   });
#   </script>
# <!-- Page hiding snippet  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#   h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#   (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#   })(window,document.documentElement,'async-hide','dataLayer',4000,
#   {'GTM-TKWQ4WC':true});</script>
# <!-- Modified Analytics tracking code with Optimize plugin -->
# <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# ...

# %%
website_ranking = soup_website_ranking.select( 'p a' )

# %%
website_ranking[ 0:10 ]
# Out:
# [<a href="https://support.alexa.com/hc/en-us/articles/200444340" target="_blank">this explanation</a>,
#  <a href="/siteinfo/google.com">Google.com</a>,
#  <a href="/siteinfo/naver.com">Naver.com</a>,
#  <a href="/siteinfo/youtube.com">Youtube.com</a>,
#  <a href="/siteinfo/daum.net">Daum.net</a>,
#  <a href="/siteinfo/tmall.com">Tmall.com</a>,
#  <a href="/siteinfo/tistory.com">Tistory.com</a>,
#  <a href="/siteinfo/google.co.kr">Google.co.kr</a>,
#  <a href="/siteinfo/sohu.com">Sohu.com</a>,
#  <a href="/siteinfo/kakao.com">Kakao.com</a>]

# %%
website_ranking[ 1 ].get_text()
# Out:
# 'Google.com'

# %%
website_ranking_address = [ website_ranking_element.get_text() for website_ranking_element in website_ranking[1:]]

# %%
website_ranking_address[0:10]
# Out:
# ['Google.com',
#  'Naver.com',
#  'Youtube.com',
#  'Daum.net',
#  'Tmall.com',
#  'Tistory.com',
#  'Google.co.kr',
#  'Sohu.com',
#  'Kakao.com',
#  'Qq.com']

# %%
print( '[ Top Site in South Korea ]' )
for index in range( len( website_ranking_address ) ):
    print( '{} : {}'.format( index + 1, website_ranking_address[ index ]))
# Out:
# [ Top Site in South Korea ]
# 1 : Google.com
# 2 : Naver.com
# 3 : Youtube.com
# 4 : Daum.net
# 5 : Tmall.com
# 6 : Tistory.com
# 7 : Google.co.kr
# 8 : Sohu.com
# 9 : Kakao.com
# 10 : Qq.com
# 11 : Login.tmall.com
# 12 : Facebook.com
# 13 : Taobao.com
# 14 : Wikipedia.org
# 15 : Jd.com
# 16 : Amazon.com
# 17 : 360.cn
# 18 : Namu.wiki
# 19 : Netflix.com
# 20 : Coupang.com
# 21 : Baidu.com
# 22 : Pages.tmall.com
# 23 : Yahoo.com
# 24 : Microsoft.com
# 25 : Weibo.com
# 26 : Sina.com.cn
# 27 : Twitch.tv
# 28 : Dcinside.com
# 29 : Bing.com
# 30 : Donga.com
# 31 : Apple.com
# 32 : Adobe.com
# 33 : Stackoverflow.com
# 34 : Gmarket.co.kr
# 35 : Office.com
# 36 : 11st.co.kr
# 37 : Amazon.co.uk
# 38 : Ruliweb.com
# 39 : Ebay.com
# 40 : Nate.com
# 41 : Auction.co.kr
# 42 : Dropbox.com
# 43 : Instagram.com
# 44 : Nytimes.com
# 45 : Spotify.com
# 46 : Amazon.co.jp
# 47 : Bbc.com
# 48 : Msn.com
# 49 : Soundcloud.com
# 50 : Yahoo.co.jp

# %%
import pandas as pd

website_ranking_d = { 'WebSite': website_ranking_address }
df = pd.DataFrame( website_ranking_d, columns = [ 'WebSite' ],
                index = range( 1, len( website_ranking_address ) + 1 ) )
df.head(10)
# Out:
#          WebSite
# 1     Google.com
# 2      Naver.com
# 3    Youtube.com
# 4       Daum.net
# 5      Tmall.com
# 6    Tistory.com
# 7   Google.co.kr
# 8       Sohu.com
# 9      Kakao.com
# 10        Qq.com

# %% [markdown]
# ### Naver 뮤직 주간 음악 순위( 2020년 6월 1주차 )
#
# https://music.naver.com/listen/history/index.nhn?type=TOTAL_V2&year=2020&month=06&week=1

# %%
url = 'https://music.naver.com/listen/history/index.nhn?type=TOTAL_V2&year=2020&month=06&week=1'

# %%
html_music = requests.get( url ).text
soup_music = BeautifulSoup( html_music, 'lxml' )

# %%
titles = soup_music.select( 'a._title span.ellipsis' )
artists = soup_music.select( 'td._artist a' )

# %%
music_titles = [ title.get_text().strip() for title in titles ]     # .strip()은 공백들을 줄이기 위해/ 웹페이지 스크랩은 공백이 많이 생겨서 필요함
music_artists = [ artist.get_text().strip() for artist in artists ]

# %%
for index in range(10):
    print( '{}: {:<30s} / {:<10s}'.format(index + 1, music_titles[ index ],
                                          music_artists[ index ] ) )
# Out:
# 1: 아로하                            / 조정석
# 2: 에잇(Prod.&Feat. SUGA of BTS)    / 아이유(IU)
# 3: 사랑하게 될 줄 알았어                   / 전미도
# 4: 살짝 설렜어 (Nonstop)               / 오마이걸(OH MY GIRL)
# 5: 좋은 사람 있으면 소개시켜줘                / 조이 (JOY)
# 6: 화려하지 않은 고백                     / 규현(KYUHYUN)
# 7: Dolphin                        / 오마이걸(OH MY GIRL)
# 8: MORE & MORE                    / TWICE(트와이스)
# 9: 그대 고운 내사랑                      / 어반자카파
# 10: 나비와 고양이 (Feat. 백현 (BAEKHYUN))  / 볼빨간사춘기

# %% [markdown]
# ## Selenium
#
# - Selenium은 웹 브라우저를 컨트롤 하여 웹 UI를 Automation 하는 도구이다.
# - Selenium은 Selenium Server와 Selenium Client가 있는데, 로컬 컴퓨터의 웹 브라우저를 컨트롤 하기 위해서는 Selenium Client를 사용한다
# - Selenium Client는 WebDriver라는 공통 인터페이스와 각 브라우저 타입별( IE, chrome, FireFox 등 )로 하나씩 있는 Browser Driver로 구성되어 있다.
# - Selenium을 설치하기 위해서는 먼저 아래와 같이 pip를 사용하여 Selenium Client 모듈을 설치한다.
#
#
#     anaconda: conda install selenium
#
#     python : pip install selenium
#
# - 사용할 브라우저별 Selenium Driver를 설치한다. driver가 설치 된 후, 해당 드라이버의 경로를 실행 PATH에 등록한다.
#
#     Firefox : https://github.com/mozilla/geckodriver/releases
#
#     Chrome : https://sites.google.com/a/chromium.org/chromedriver/downloads

# %%
from selenium import webdriver

# %%
brower = webdriver.Chrome()
brower.get( 'http://python.org' )   # 이렇게 나와야 잘 깔린 것 (아나콘다3에 압축 풀어야 함)

# %%
import time

browser = webdriver.Chrome()
browser.get( 'http://python.org' )

menus = browser.find_elements_by_css_selector( '#top ul.menu li' )

pypi = None
for m in menus:
    if m.text == 'PyPI':
        pypi = m
    print( m.text )
    
time.sleep( 5 )    
pypi.click()    # 이 스크립트가 pypi를 클릭해줌
# Out:
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community

# %%
browser = webdriver.Chrome()
browser.get( 'http://www.naver.com' )

menus = browser.find_elements_by_css_selector( '#NM_FAVORITE ul li' )

naver_map = None
for m in menus:
    if m.text == '지도':
        naver_map = m
    print( m.text )
    
time.sleep( 5 )    
naver_map.click()
# Out:
# 메일
# 카페
# 블로그
# 지식iN
# 쇼핑
# Pay
# TV
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# 영화
# 뮤직
# 책
# 웹툰
