# %%
import webbrowser

# %%
url = 'www.naver.com'

webbrowser.open( url )
# Out:
# True

# %%
import urllib.request

# %%
naver = urllib.request.urlopen('https://www.naver.com')

# %%
naver.read()
# Out:
# b'\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x8
# ...

# %%
import requests

# %%
response = requests.get( 'https://www.naver.com')

# %%
response.text
# Out:
# '\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인
# ...

# %%
from bs4 import BeautifulSoup

# %%
html = '''
<html>
    <body>
        <div>
            <span>
                <a href=https://www.naver.com>naver</a>
                <a href=https://www.google.com>google</a>
                <a href=https://www.daum.com>daum</a>
            </span>
        </div>
    </body>  
</html>    
'''

# %%
soup = BeautifulSoup( html, 'lxml')
soup
# Out:
# <html>
# <body>
# <div>
# <span>
# <a href="https://www.naver.com">naver</a>
# <a href="https://www.google.com">google</a>
# <a href="https://www.daum.com">daum</a>
# </span>
# </div>
# </body>
# </html>

# %%
soup.find( 'span').get_text()
# Out:
# '\nnaver\ngoogle\ndaum\n'

# %%
soup.find( 'a' ).get_text()
# Out:
# 'naver'

# %%
soup.find_all('a').get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-9126f559522e> in <module>
# ----> 1 soup.find_all('a').get_text()
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2159         """Raise a helpful exception to explain a common code fix."""
#    2160         raise AttributeError(
# -> 2161             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2162         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
site_names = soup.find_all( 'a' )
for site_names in site_names:
    print( site_names.get_text() )

# %%
html = '''
<html>
    <head>
        <title>작품과 작가 모음</title>
    </head>
    <body>
        <h1>책 정보</h1>
        <p id= "book_title">토지</p> 
        <p id= "author">박경리</p>
        
        <p id= "book_title">태백산맥</p>
        <p id= "author">조정래</p>
        
        <p id= "book_title">감옥으로부터의 사색</p>
        <p id= "author">신영복</p>
    </body>
</html>    
'''

# %%
soup2 = BeautifulSoup( html, 'lxml' )
soup2
# Out:
# <html>
# <head>
# <title>작품과 작가 모음</title>
# </head>
# <body>
# <h1>책 정보</h1>
# <p id="book_title">토지</p>
# <p id="author">박경리</p>
# <p id="book_title">태백산맥</p>
# <p id="author">조정래</p>
# <p id="book_title">감옥으로부터의 사색</p>
# <p id="author">신영복</p>
# </body>
# </html>

# %%
soup2.find_all('p',{'id':"book_title"} )
# Out:
# [<p id="book_title">토지</p>,
#  <p id="book_title">태백산맥</p>,
#  <p id="book_title">감옥으로부터의 사색</p>]

# %%
soup2.select('p#author')
# Out:
# [<p id="author">박경리</p>, <p id="author">조정래</p>, <p id="author">신영복</p>]

# %%
soup2.select('p#book_title')
# Out:
# [<p id="book_title">토지</p>,
#  <p id="book_title">태백산맥</p>,
#  <p id="book_title">감옥으로부터의 사색</p>]

# %%
soup2.find_all('p')
# Out:
# [<p id="book_title">토지</p>,
#  <p id="author">박경리</p>,
#  <p id="book_title">태백산맥</p>,
#  <p id="author">조정래</p>,
#  <p id="book_title">감옥으로부터의 사색</p>,
#  <p id="author">신영복</p>]

# %%
b=soup2.select('p#book_title')
a=soup2.select('p#author')
for b, a in zip(b, a):
    print('{}  /  {}'.format(b.get_text(), a.get_text()))
# Out:
# 토지  /  박경리
# 태백산맥  /  조정래
# 감옥으로부터의 사색  /  신영복

# %%
soup2.h1
# Out:
# <h1>책 정보</h1>

# %%
# %%writefile HTML_Basic2.html
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="utf-8">
#         <title>사이트 모음</title>
#     </head>
#     <body>
#         <p id="title"><b>자주 가는 사이트 모음</b></p>
#         <p id="contents"><b>이곳은 자주 가는 사이트를 모아둔 곳입니다.</p>
#         <a href="https://www.naver.com" class="potal">네이버</a><br>
#         <a href="https://www.google.com" class="search">구글</a><br>
#         <a href="https://www.daum.net" class="potal" id="daum">다음</a><br>
#         <a href="https://www.nl.go.kr" class="goverment" id="nl">국립중앙도서관</a>
#     </body>
# </html>
# Out:
# Writing HTML_Basic2.html

# %%
with open('HTML_Basic2.html', encoding = 'utf-8') as f:
    html = f.read()
soup3 = BeautifulSoup( html, 'lxml')

# %%
soup3
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>사이트 모음</title>
# </head>
# <body>
# <p id="title"><b>자주 가는 사이트 모음</b></p>
# <p id="contents"><b>이곳은 자주 가는 사이트를 모아둔 곳입니다.</b></p>
# <a class="potal" href="https://www.naver.com">네이버</a><br/>
# <a class="search" href="https://www.google.com">구글</a><br/>
# <a class="potal" href="https://www.daum.net" id="daum">다음</a><br/>
# <a class="goverment" href="https://www.nl.go.kr" id="nl">국립중앙도서관</a>
# </body>
# </html>

# %%
soup3.select('a.potal')
# Out:
# [<a class="potal" href="https://www.naver.com">네이버</a>,
#  <a class="potal" href="https://www.daum.net" id="daum">다음</a>]

# %%
soup3.select('a.goverment')[0].get_text()
# Out:
# '국립중앙도서관'

# %%
url = 'https://sports.news.naver.com/kbaseball/schedule/index.nhn'
kbo = requests.get(url).text
soup_kbo = BeautifulSoup( kbo, 'lxml')

# %%
soup_kbo
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image"/>
# <meta content="네이버 스포츠" property="og:title"/>
# <meta content="스포츠의 시작과 끝!" property="og:description"/>
# <meta content="sports.news.naver.com/kbaseball/schedule/index.nhn?category=kbo" property="og:url"/>
# <title>일정/결과, 야구 : 네이버 스포츠</title>
# <!-- common css-->
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2020/06/24/155307/css/common_loose_new.css" rel="stylesheet" type="text/css"/>
# <!-- category-self css-->
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2020/06/24/155307/css/baseball_gamecenter.css" rel="stylesheet" type="text/css"/>
# ...

# %%
lk = soup_kbo.select('td strong.td_score ')[0:10]
lk
# Out:
# [<strong class="td_score">2<em>:</em>7</strong>,
#  <strong class="td_score">11<em>:</em>8</strong>,
#  <strong class="td_score">8<em>:</em>2</strong>,
#  <strong class="td_score">2<em>:</em>0</strong>,
#  <strong class="td_score">15<em>:</em>3</strong>,
#  <strong class="td_score">2<em>:</em>11</strong>,
#  <strong class="td_score">2<em>:</em>7</strong>,
#  <strong class="td_score">6<em>:</em>8</strong>,
#  <strong class="td_score">12<em>:</em>6</strong>,
#  <strong class="td_score">6<em>:</em>2</strong>]

# %%
kboscore = [ a.get_text() for a in lk[0:10] ]

# %%
kboscore
# Out:
# ['2:7', '11:8', '8:2', '2:0', '15:3', '2:11', '2:7', '6:8', '12:6', '6:2']

# %%
import numpy as np

# %%
s1 = { 'kboscore':kboscore}
df = pd.DataFrame( s1, columns = ['kboscore'])
df
# Out:
#   kboscore
# 0      2:7
# 1     11:8
# 2      8:2
# 3      2:0
# 4     15:3
# 5     2:11
# 6      2:7
# 7      6:8
# 8     12:6
# 9      6:2

# %%
import pandas as pd

# %%
df = { 'Score':lk }

# %%
from selenium import webdriver

# %%
bs = webdriver.Chrome()
bs.get('http://python.org')

# %%
import time
import requests

# %%
import math
import time
