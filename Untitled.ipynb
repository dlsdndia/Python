# %%
number1 = int(input('number : '))
# Out:
# number : 25

# %%
print( '선택 숫자 : ({:})임'.format(number1))
# Out:
# 선택 숫자 : (25)임

# %%
l = [ 1, 2, 'python' ]                     # list는 반드시 대괄호[]가 있어야 함, 콤마만 있으면 튜플 / 자료형이 같이 필요 없음
print( 'l : {}\nlen( l ) : {}'.format( l, len( l ) ) )
# Out:
# l : [1, 2, 'python']
# len( l ) : 3

# %%
str = "Python is great!!!"
print( "str : {}\tlength : {}\n".format( str, len( str ) ) )
# Out:
# str : Python is great!!!	length : 18

# %%
print( "P" in str )
print( 'p' in str )
print( 'Python' in str )
print( 'is' in str )
print( 'th' in str, '\n' )
# Out:
# True
# False
# True
# True
# True

# %%
# str[ 0 ] = 'p'      str 0번째를 p로 바꿔라 하지만 자료형이 변경 불가형 자료형이라 안됨
print( str, '\n' )
# Out:
# Python is great!!!

# %%
student_info = { 20140012:'Hong', 20140059:'Kim', 20140058:'lee'}
member = { 'baskitball':5, 'soccer':11, 'baseball':9 }
d = {}     # 빈 dict 생성
print( 'ㅇ : {}\n'.format( d ) )
# Out:
# ㅇ : {}

# %%
print( 'student_info keys : {}'.format( student_info.keys() ) )       # key값 나옴
print( 'member keys : {}'.format( member.keys() ) )
print( 'd keys : {}\n'.format( d.keys() ) )

print( 'student_info values : {}'.format( student_info.values() ) )   # 값이 나옴
print( 'member values : {}'.format( member.values() ) )
print( 'd values : {}\n'.format( d.values() ) )

print( 'student_info items : {}'.format( student_info.items() ) )     # 전체 데이터를 알고자 할 때
print( 'member items : {}'.format( member.items() ) )
print( 'd items : {}\n'.format( d.items() ) )

print( 'student_info items : {}'.format( student_info.items() ) )     # 전체 데이터를 알고자 할 때
print( 'member items : {}'.format( member.items() ) )
print( 'd items : {}\n'.format( d.items() ) )
# Out:
# student_info keys : dict_keys([20140012, 20140059, 20140058])
# member keys : dict_keys(['baskitball', 'soccer', 'baseball'])
# d keys : dict_keys([])
#
# student_info values : dict_values(['Hong', 'Kim', 'lee'])
# member values : dict_values([5, 11, 9])
# d values : dict_values([])
#
# student_info items : dict_items([(20140012, 'Hong'), (20140059, 'Kim'), (20140058, 'lee')])
# member items : dict_items([('baskitball', 5), ('soccer', 11), ('baseball', 9)])
# d items : dict_items([])
#
# student_info items : dict_items([(20140012, 'Hong'), (20140059, 'Kim'), (20140058, 'lee')])
# member items : dict_items([('baskitball', 5), ('soccer', 11), ('baseball', 9)])
# d items : dict_items([])

# %%
number = int(input('입력값 : '))
# Out:
# 입력값 : 9

# %%
if number >=8:
    print(" ㅅㅅ ")
else:
    print(" ㄴㄴ ")
# Out:
#  ㅅㅅ

# %%
dd = {'spam':500, 'bob':1000, 'spagetti':10000} 
dd
# Out:
# {'spam': 500, 'bob': 1000, 'spagetti': 10000}

# %%
oder = input( " 주문 : ")
# Out:
#  주문 : spam

# %%
price = dd.get(oder)

# %%
if oder == 'spam':
    print('{}원'.format(price))
elif oder == 'bob':
    print('{}원'.format(price))
elif oder == 'spagetti':
    print('{}원'.format(price))
# Out:
# 500원

# %%
print( ' max : {}   mid : {}  min : {}'.format(max, mid, min))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-7528fa109f5e> in <module>
# ----> 1 print( ' max : {}   mid : {}  min : {}'.format(max, mid, min))
#
# NameError: name 'mid' is not defined

# %%
#x = 1; y = 2; z = 3
# x = 1; y = 3; z = 2
# x = 2; y = 1; z = 3
# x = 2; y = 3; z = 1
# x = 3; y = 1; z = 2
# x = 3; y = 2; z = 1
x = 125465887; y = 687421654; z = 65746854354685

# %%
if x > y:
    if x > z:
        max = x
        if y > z:
            mid = y
            min = z
        elif z> y:
            mid = z
            min = y
    elif z > x:
        max = z
        mid = x
        min = y
elif y > z:
    max = y
    mid = z
    min = x
else:
    max = z
    mid = y
    min = x

# %%
print('max : {}\tmid : {}\tmin : {}'.format(max, mid, min))
# Out:
# max : 65746854354685	mid : 687421654	min : 125465887

# %% [markdown]
# 다음의 결과와 같이 5명의 학생의 점수에 대해 60 이상일 때 합격 메시지를 출력하고,
#
# 60미만일 때 불합격 메시지를 출력하는 프로그램을 만드십시오.

# %%
score = [ 30, 40, 50, 60, 70 ]

# %%
for i in score:
    if i >= 60:
        print( '합격' )
    else:
        print( '불합격' )
# Out:
# 불합격
# 불합격
# 불합격
# 합격
# 합격

# %% [markdown]
# 다음은 10명의 학생들의 혈액형(A, B, AB, O) 데이터입니다.
#
# ['A', 'A', 'A', 'O', 'B', 'B', 'O', 'AB', 'AB', 'O']
#
# for 문을 이용하여 각 혈액형 별 학생수를 구하십시오.

# %%
blood = ['A', 'A', 'A', 'O', 'B', 'B', 'O', 'AB', 'AB', 'O']

# %%
A = []
B = []
O = []
AB = []

# %%
for i in blood:
    i == 'A'

# %%
A
# Out:
# []

# %%
result = {"A" : 0, "B" : 0, "AB" : 0, "O" : 0}
students = ['A', 'A', 'A', 'O', 'B', 'B', 'O', 'AB', 'AB', 'O']
#반복문을 돌면서 딕셔너리 값 증가
for s in students:
   result[s] += 1
print("{'A': %d, 'O': %d, 'B': %d, 'AB': %d}" % (result["A"], result["O"], result["B"], result["AB"]))
# Out:
# {'A': 3, 'O': 3, 'B': 2, 'AB': 2}
