# %% [markdown]
# # 서울시 주민등록인구 내국인 각세별동별 통계 분석

# %% [markdown]
# ### Hwang in woo
# - 06/22

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv( '3.서울시 주민등록인구 내국인 각세별동별 통계.txt', sep = '\t', encoding = 'utf-8')
data
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       -       -       -       -       -
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...

# %%
per = []
dis = []
vil = []
total= []
one = []
ten = []
twenty = []
thirty = []
forty = []
fifty = []
sixty = []
seventy = []
eighty = []
ninety = []
hund = []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Columns: 105 entries, 기간 to 100세 이상+
# dtypes: object(105)
# memory usage: 370.1+ KB

# %%
data.shape
# Out:
# (451, 105)

# %%
data.dtypes
# Out:
# 기간          object
# 자치구         object
# 동           object
# 합계          object
# 0세          object
#              ...
# 96세         object
# 97세         object
# 98세         object
# 99세         object
# 100세 이상+    object
# Length: 105, dtype: object

# %%
data.columns[4: ].map(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-0ab9567d87f3> in <module>
# ----> 1 data.columns[4: ].map(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in map(self, mapper, na_action)
#    4563         from pandas.core.indexes.multi import MultiIndex
#    4564
# -> 4565         new_values = super()._map_values(mapper, na_action=na_action)
#    4566
#    4567         attributes = self._get_attributes_dict()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1152
#    1153         # mapper is a function
# -> 1154         new_values = map_f(values, mapper)
#    1155
#    1156         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: invalid literal for int() with base 10: '0세'

# %%
data
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       -       -       -       -       -
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...

# %%
a1 = data[ '0세' ]
a1
# Out:
# 0      49,051
# 1         603
# 2          38
# 3           8
# 4          44
#         ...
# 446         -
# 447       139
# 448       190
# 449       172
# 450       202
# Name: 0세, Length: 451, dtype: object

# %%
for i in a1:
    if i == '-':
        
        i.replace('-','0')
# Out:
# -

# %%
a1
# Out:
# 0      49,051
# 1         603
# 2          38
# 3           8
# 4          44
#         ...
# 446         -
# 447       139
# 448       190
# 449       172
# 450       202
# Name: 0세, Length: 451, dtype: object

# %%
for i in a1:
    print( i )
# Out:
# 49,051
# 603
# 38
# 8
# 44
# 85
# 36
# 80
# 11
# 14
# 7
# 27
# 13
# 17
# 53
# 22
# 30
# 69
# 49
# 660
# 14
# 12
# 4
# 6
# 13
# 17
# 6
# 61
# 88
# 114
# 28
# 60
# 100
# 77
# 60
# 1,171
# 80
# 44
# 17
# 85
# 74
# 73
# 165
# 61
# 19
# 37
# 47
# 30
# 59
# 154
# 109
# 117
# 2,001
# 113
# 108
# 42
# 81
# 169
# 101
# 145
# 152
# 101
# 84
# 79
# 57
# 53
# 28
# 212
# 209
# 267
# 1,646
# 46
# 66
# 84
# 105
# 65
# 151
# 67
# 87
# 146
# 186
# 148
# 97
# 150
# 181
# 67
# 1,812
# 33
# 71
# 75
# 56
# 134
# 76
# 181
# 83
# 192
# 239
# 254
# 42
# 107
# 269
# 1,942
# 99
# 99
# 45
# 120
# 163
# 103
# 132
# 117
# 197
# 118
# 61
# 187
# 101
# 155
# 127
# 118
# 2,154
# 82
# 112
# 50
# 89
# 103
# 108
# 75
# 139
# 201
# 140
# 135
# 90
# 75
# 46
# 152
# 85
# 87
# 42
# 182
# 161
# 1,119
# 65
# 58
# 66
# 81
# 73
# 78
# 105
# 53
# 111
# 79
# 148
# 78
# 124
# 1,401
# 82
# 92
# 75
# 76
# 90
# 79
# 134
# 113
# 150
# 52
# 120
# 125
# 67
# 146
# 2,449
# 97
# 114
# 195
# 214
# 95
# 89
# 54
# 44
# 66
# 201
# 63
# 79
# ...

# %%
data.loc[data['0세'] == '-' ] = 0

# %%
data['0세']
# Out:
# 0      49,051
# 1         603
# 2          38
# 3           8
# 4          44
#         ...
# 446         0
# 447       139
# 448       190
# 449       172
# 450       202
# Name: 0세, Length: 451, dtype: object

# %%
data.loc[ data['0세':'100세 이상+'] == '-' ] = 0
# Out:
#   File "<ipython-input-194-e34e488be283>", line 1
#     data.loc[ data['0세':'100세 이상+'] == '-', axis = 1 ] = 0
#                                                  ^
# SyntaxError: invalid syntax

# %%
data.loc[0:] == '-'
# Out:
#         기간    자치구      동     합계     0세     1세     2세     3세     4세     5세  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 446  False  False  False  False  False   True   True   True   True  False
# 447  False  False  False  False  False  False  False  False  False  False
# 448  False  False  False  False  False  False  False  False  False  False
# 449  False  False  False  False  False  False  False  False  False  False
# 450  False  False  False  False  False  False  False  False  False  False
#
#      ...    91세    92세    93세    94세    95세    96세    97세    98세    99세  \
# ...

# %%
data.loc[data['0세'] == '-' ] = 0

# %%
coll = data[ '0세':'100세 이상+' ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-33c04ad4711f> in <module>
# ----> 1 coll = data[ '0세':'100세 이상+' ]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2777
#    2778         # Do we have a slicer (on rows)?
# -> 2779         indexer = convert_to_index_sliceable(self, key)
#    2780         if indexer is not None:
#    2781             # either we have a slice or we have a string that can be converted
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2264     idx = obj.index
#    2265     if isinstance(key, slice):
# -> 2266         return idx._convert_slice_indexer(key, kind="getitem")
#    2267
#    2268     elif isinstance(key, str):
#
# ...

# %%
data.loc[data['0세'] == '-' ] = 0

# %%
coll = [ data['0세']:data['100세'] ]
# Out:
#   File "<ipython-input-198-ac53bdddb27c>", line 1
#     coll = [ data['0세']:data['100세'] ]
#                        ^
# SyntaxError: invalid syntax

# %%
data[data.loc[:] == '-'] = '0'

# %%
data
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       0       0       0       0       0
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...
