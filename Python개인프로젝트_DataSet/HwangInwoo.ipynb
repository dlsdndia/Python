# %% [markdown]
# # 서울시 주민등록인구 내국인 각세별동별 통계 분석

# %% [markdown]
# ### Hwang in woo
# - 06/22

# %%
# 패키지 불러오기
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. 파일 읽고 DataFrame으로 생성과정

# %% [markdown]
# ### 1-1. 데이터 읽고 확인하기

# %%
# 파일 읽기
data = pd.read_csv( '3.서울시 주민등록인구 내국인 각세별동별 통계.txt', sep = '\t', encoding = 'utf-8')
data
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       -       -       -       -       -
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...

# %% [markdown]
# ### 1-2. 데이터 속성 확인하기

# %%
# 데이터 속성 확인하기
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Columns: 105 entries, 기간 to 100세 이상+
# dtypes: object(105)
# memory usage: 370.1+ KB

# %%
data.shape
# Out:
# (451, 105)

# %%
data.dtypes
# Out:
# 기간          object
# 자치구         object
# 동           object
# 합계          object
# 0세          object
#              ...
# 96세         object
# 97세         object
# 98세         object
# 99세         object
# 100세 이상+    object
# Length: 105, dtype: object

# %% [markdown]
# ### 1-3. 결측치 확인하기

# %%
# 결측치 확인하기 
data.isnull()
# Out:
#         기간    자치구      동     합계     0세     1세     2세     3세     4세     5세  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 446  False  False  False  False  False  False  False  False  False  False
# 447  False  False  False  False  False  False  False  False  False  False
# 448  False  False  False  False  False  False  False  False  False  False
# 449  False  False  False  False  False  False  False  False  False  False
# 450  False  False  False  False  False  False  False  False  False  False
#
#      ...    91세    92세    93세    94세    95세    96세    97세    98세    99세  \
# ...

# %%
# 전체 데이터에서 '-'값 확인하기
f = data.loc[0:] == '-'         # 전체 데이터에서 '-'값 확인하기
s = f.sum()                     # 변수마다 '-'개수 합하기
s.sum()                         # 각 변수  '-'개수를 합해서 총합 구하기
# Out:
# 148

# %% [markdown]
# ### 1-3. '-'값을 0으로 바꾸기
# - 0세~100세 이상까지 인원을 나타내는 데이터이기 때문에 평균을 넣으면 데이터의 의미가 훼손될 수 있기 때문에 0으로 넣었음
# - '-'값을 0으로 대체해도 큰 문제가 없다고 판단

# %%
data[data.loc[:] == '-'] = '0'

# %%
data
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       0       0       0       0       0
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...

# %%
# 0으로 대체한 데이터의 값 다시 확인해보기
f = data.loc[0:] == '-'        
s = f.sum()                     
s.sum()                         

# '-'의 값이 0으로 전부 0으로 바뀜
# Out:
# 0

# %% [markdown]
# ## 2. 문제 정의
# - 1. 각 자치구에 거주하는 연령별 인구
# - 2. 청년(나이)기준 많이 거주하는 자치구
# - 3. 노인(나이)기준 많이 거주하는 자치구
# - 4. 출산률(0세)기준 많은 자치구

# %% [markdown]
# ### 2-1. 통계 및 연산에 편하게 변수 줄이기 (문제 정의 기준)

# %%
data2 = data

# %%
data2.drop[ '0세':'1세']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-1f962818ff0b> in <module>
# ----> 1 data2.drop[ '0세':'1세']
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# ## 3. 기본 통계 분석

# %% [markdown]
# ### 3-1. 데이터 요약 정보

# %%
data.describe()
# Out:
#               기간  자치구    동      합계   0세   1세   2세   3세   4세   5세  ...  91세  \
# count        451  451  451     451  451  451  451  451  451  451  ...  451
# unique         1   26  426     450  224  232  233  243  259  266  ...   74
# top     2020.1/4  송파구   소계  22,946   66  123  129   84  125  197  ...   16
# freq         451   28   25       2    7    7    6    7    7    7  ...   30
#
#         92세  93세  94세  95세  96세  97세  98세  99세 100세 이상+
# count   451  451  451  451  451  451  451  451      451
# unique   65   56   51   44   42   38   35   29       70
# top      11   10    8    4    4    4    2    2        9
# freq     33   35   45   55   62   70   99  106       34
#
# [4 rows x 105 columns]
