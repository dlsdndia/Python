# %%
import pandas as pd

# %%
df = pd.read_csv('3.서울시 주민등록인구 내국인 각세별동별 통계.txt',sep = '\t', encoding = 'utf-8')

# %%
df
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       -       -       -       -       -
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...

# %%
    df[df.loc[:] == '-' ] = '0'

# %%
df
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       0       0       0       0       0
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...

# %%
st = df.loc[(~df['동'].str.contains('소계'))]

# %%
st=st.drop(0,axis=0)

# %%
st
# Out:
#            기간  자치구     동      합계   0세   1세   2세   3세   4세   5세  ... 91세 92세  \
# 2    2020.1/4  종로구   사직동   9,553   38   38   46   68   58   83  ...  19  12
# 3    2020.1/4  종로구   삼청동   2,749    8    5   17    5   14   11  ...   3   6
# 4    2020.1/4  종로구   부암동  10,164   44   35   48   52   50   66  ...  16  12
# 5    2020.1/4  종로구   평창동  18,609   85   86  101   96  139  139  ...  29  22
# 6    2020.1/4  종로구   무악동   8,720   36   44   63   76   77   79  ...  10   9
# ..        ...  ...   ...     ...  ...  ...  ...  ...  ...  ...  ...  ..  ..
# 446  2020.1/4  강동구  둔촌1동     266    0    0    0    0    0    2  ...   1   1
# 447  2020.1/4  강동구  둔촌2동  27,376  139  162  166  202  191  213  ...  26  20
# 448  2020.1/4  강동구  암사1동  36,178  190  228  228  215  251  239  ...  23  22
# 449  2020.1/4  강동구  천호2동  34,925  172  226  182  199  220  166  ...  27  23
# 450  2020.1/4  강동구    길동  45,731  202  223  227  268  283  293  ...  28  28
#
#     93세 94세 95세 96세 97세 98세 99세 100세 이상+
# ...

# %%
df.dtypes
# Out:
# 기간          object
# 자치구         object
# 동           object
# 합계          object
# 0세          object
#              ...
# 96세         object
# 97세         object
# 98세         object
# 99세         object
# 100세 이상+    object
# Length: 105, dtype: object

# %%
df.str.replace(',', '').astype('int64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-56a504bfb04a> in <module>
# ----> 1 df.str.replace(',', '').astype('int64')
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df
# Out:
#            기간  자치구     동         합계      0세      1세      2세      3세      4세  \
# 0    2020.1/4   합계    합계  9,733,655  49,051  54,104  57,361  63,603  69,433
# 1    2020.1/4  종로구    소계    151,217     603     580     660     758     840
# 2    2020.1/4  종로구   사직동      9,553      38      38      46      68      58
# 3    2020.1/4  종로구   삼청동      2,749       8       5      17       5      14
# 4    2020.1/4  종로구   부암동     10,164      44      35      48      52      50
# ..        ...  ...   ...        ...     ...     ...     ...     ...     ...
# 446  2020.1/4  강동구  둔촌1동        266       0       0       0       0       0
# 447  2020.1/4  강동구  둔촌2동     27,376     139     162     166     202     191
# 448  2020.1/4  강동구  암사1동     36,178     190     228     228     215     251
# 449  2020.1/4  강동구  천호2동     34,925     172     226     182     199     220
# 450  2020.1/4  강동구    길동     45,731     202     223     227     268     283
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Columns: 105 entries, 기간 to 100세 이상+
# dtypes: object(105)
# memory usage: 370.1+ KB

# %%
df.shape
# Out:
# (451, 105)

# %%
df.dtypes
# Out:
# 기간          object
# 자치구         object
# 동           object
# 합계          object
# 0세          object
#              ...
# 96세         object
# 97세         object
# 98세         object
# 99세         object
# 100세 이상+    object
# Length: 105, dtype: object

# %%
df.drop('기간', axis = 1, inplace = True )

# %%
df2 = df.loc[:,['자치구','동','합계']]
df2
# Out:
#      자치구     동         합계
# 0     합계    합계  9,733,655
# 1    종로구    소계    151,217
# 2    종로구   사직동      9,553
# 3    종로구   삼청동      2,749
# 4    종로구   부암동     10,164
# ..   ...   ...        ...
# 446  강동구  둔촌1동        266
# 447  강동구  둔촌2동     27,376
# 448  강동구  암사1동     36,178
# 449  강동구  천호2동     34,925
# 450  강동구    길동     45,731
#
# [451 rows x 3 columns]

# %%
df3 = df.iloc[:,3:103]
df3
# Out:
#          0세      1세      2세      3세      4세      5세      6세      7세      8세  \
# 0    49,051  54,104  57,361  63,603  69,433  69,302  68,512  74,935  73,492
# 1       603     580     660     758     840     848     862     999     903
# 2        38      38      46      68      58      83      76      80      62
# 3         8       5      17       5      14      11      14      10      17
# 4        44      35      48      52      50      66      69      88      68
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 446       0       0       0       0       0       2       0       3       0
# 447     139     162     166     202     191     213     209     223     191
# 448     190     228     228     215     251     239     230     263     251
# 449     172     226     182     199     220     166     156     175     189
# 450     202     223     227     268     283     293     260     281     293
#
# ...

# %%
df3 = df3.apply( pd.to_numeric )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "49,051"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-211-f17894101623> in <module>
# ----> 1 df3 = df3.apply( pd.to_numeric )
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# C:\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
# ...

# %%
df3.iloc[0]
# Out:
# 0세     49,051
# 1세     54,104
# 2세     57,361
# 3세     63,603
# 4세     69,433
#         ...
# 95세     2,427
# 96세     2,326
# 97세     1,913
# 98세     1,350
# 99세       996
# Name: 0, Length: 100, dtype: object

# %%
df3.iloc[0]
# Out:
# 0세     49,051
# 1세     54,104
# 2세     57,361
# 3세     63,603
# 4세     69,433
#         ...
# 95세     2,427
# 96세     2,326
# 97세     1,913
# 98세     1,350
# 99세       996
# Name: 0, Length: 100, dtype: object

# %%
df3.dtypes
# Out:
# 동      float64
# 합계     float64
# 0세     float64
# 1세     float64
# 2세     float64
#         ...
# 94세    float64
# 95세    float64
# 96세    float64
# 97세    float64
# 98세    float64
# Length: 101, dtype: object

# %%
df1 = pd.concat( [ df2, df3 ], axis = 1 )

# %%
df1.dtypes
# Out:
# 자치구          object
# 동            object
# 0세          float64
# 1세          float64
# 2세          float64
#              ...
# 96세         float64
# 97세         float64
# 98세         float64
# 99세           int64
# 100세 이상+    float64
# Length: 103, dtype: object
