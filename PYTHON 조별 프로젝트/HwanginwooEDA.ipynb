# %% [markdown]
# # 종합 에너지 데이터(신.재생에너지 생산량) EDA

# %% [markdown]
# ### Hwang In Woo

# %% [markdown]
# ## 목차
# 1. 사전 준비
#
#
# 2. 변수 설명
#
#
# 3. 연도별 신.재생에너지 총 생산량
#
#
# 4. 2015년 지역별 신.재생에너지 총 생산량
#
#
# 5. 2016년 지역별 신.재생에너지 총 생산량
#
#
# 6. 2017년 지역별 신.재생에너지 총 생산량
#
#
# 7. 2018년 지역별 신.재생에너지 총 생산량
#
#
# 8. 연도별 신.재생에너지 총 생산량 그래프 정리
#
#
# 9. 연도별 신.재생에너지 총 생산량 비율
#
#
# 10. 신.재생에너지 총 발전량
#
#
# 11. EDA 결과

# %% [markdown]
# ## 1. 사전 준비

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from matplotlib import style

# %%
from matplotlib import font_manager, rc
font_path = 'c://Windows//Fonts//malgun.ttf' # 폰트 파일 위치
font_name = font_manager.FontProperties( fname = font_path ).get_name()
rc( 'font', family = font_name )

# %% [markdown]
# ## 2. 변수 설명
# *2-1. 연도별 재.생산에너지 생산량
#
# * 단위(toe) = 지구상에 존재하는 모든 에너지원의 발열량에 기초해서 이를 석유의 발열량으로 환산한 것으로 석유환산톤을 말한다. 각종 에너지의 단위를 비교하기 위한 가상단위라고 볼 수 있다. 1톤의 석유를 완전연소시킬때 얻을 수 있는 에너지량
#
#
# - 총1차에너지(천toe) : 에너지원 중 천연자원 상태에서 공급되는 에너지(석유, 석탄, 천연가스 등)
# - 신·재생에너지 공급비중(%) : 총 에너지에서 신에너지와 재생에너지의 공급비중을 합한 %비율
# - 재생에너지(공급비중) : 총에너지에서 재생에너지의 공급비중 %비율
# - 신에너지(공급비중) : 총에너지에서 신에너지의 공급비중 %비율
# - 신·재생에너지 합계(toe) : 신에너지와 재생에너지 생란량 합계
# - 재생에너지 : 재생에너지 생산량
# - 신에너지: 신에너지 생산량
#
#
#
# *2-2. 연도별 재.생산에너지 생산량
#
#
# - 각 지역 : 대도시와 각 도별
# - 신·재생에너지 합계(toe) : 각 지역별 신.재생에너지 생산량
# - 재생에너지 : 각 지역별 재생에너지 생산량
# - 신에너지 : 각 지역별 신에너지 생산량

# %% [markdown]
# ### 3. 연도별 신.재생에너지 총 생산량

# %%
df = pd.read_excel( '(통계표1) 2018년 신재생에너지 보급통계(2019년 공표)_연도별_지역별 현황_한국에너지공단.xlsx' )

# %%
df
# Out:
#                                     1. 연도별 신·재생에너지 현황 Unnamed: 1 Unnamed: 2  \
# 0                                                 NaN        NaN        NaN
# 1                                 1.1 연도별 신·재생에너지 생산량        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 구 분        NaN        NaN
# 4                                        총1차에너지(천toe)        NaN        NaN
# ..                                                ...        ...        ...
# 58                                  주3) '11년부터 TDF 추가        NaN        NaN
# 59                 주4) '14년부터 RDF/RPF/TDF는 SRF로 대체 조사        NaN        NaN
# 60          주5) '14년부터 우드칩, 목재펠릿 중 일부는 Bio-SRF로 대체 분류        NaN        NaN
# 61                      주6) '15년부터 대형도시쓰레기는 생활폐기물로 포함        NaN        NaN
# 62  주7) '17년부터 임산연료는 행정자료 제공 기관(산림청 : 임산통계연보)의 통계수...        NaN        NaN
#
# ...

# %% [markdown]
# - 엑셀로 만들어진 표이다 보니 공백이 많아 결측치로 인식이 되어 결측치 처리가 필요함

# %%
df1 = df.iloc[3:12]

# %%
df1.drop('Unnamed: 2', axis = 1, inplace = True )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1.drop(['Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'], axis = 1, inplace = True )

# %%
df1.columns=['에너지_종류','세부종류','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']

# %%
df1.drop(8, inplace = True)

# %%
df1
# Out:
#              에너지_종류   세부종류         2007        2008        2009      2010  \
# 3               구 분    NaN          '07         '08         '09       '10
# 4      총1차에너지(천toe)    NaN       236678      240994      243500    264053
# 5   신·재생에너지 공급비중(%)    NaN      2.36979     2.43097     2.49949   2.59683
# 6               NaN  재생에너지      2.36902     2.42915      2.4916   2.58079
# 7               NaN   신에너지  0.000774047  0.00181208  0.00788214  0.016039
# 9   신·재생에너지 합계(toe)    NaN      5608776     5858481     6086249   6856284
# 10              NaN  재생에너지      5606944     5854113     6067056   6813938
# 11              NaN   신에너지         1832        4367       19193     42347
#
#          2011       2012       2013       2014         2015         2016  \
# 3         '11        '12        '13        '14          '15          '16
# 4      276997     278325     279623     282423       286932       293778
# 5     2.73752       3.18    3.53305    4.08514       4.6328      4.82623
# ...

# %%
df1.iloc[0,1] = '구분'
df1.iloc[1,1] = '총1차에너지(천toe)'
df1.iloc[2,1] = '신·재생에너지 공급비중(%)'
df1.iloc[3,0] = '재생에너지'
df1.iloc[4,0] = '신에너지'
df1.iloc[5,1] = '신·재생에너지 합계(toe)'
df1.iloc[6,0] = '재생에너지'
df1.iloc[7,0] = '신에너지'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df1.drop('세부종류', axis = 1, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df1.drop(3, inplace = True)

# %%
df2 = df1.T
df2
# Out:
#                   4                5        6            7                9   \
# 에너지_종류  총1차에너지(천toe)  신·재생에너지 공급비중(%)    재생에너지         신에너지  신·재생에너지 합계(toe)
# 2007          236678          2.36979  2.36902  0.000774047          5608776
# 2008          240994          2.43097  2.42915   0.00181208          5858481
# 2009          243500          2.49949   2.4916   0.00788214          6086249
# 2010          264053          2.59683  2.58079     0.016039          6856284
# 2011          276997          2.73752  2.71465    0.0228681          7582845
# 2012          278325             3.18  3.15036    0.0296452          8850739
# 2013          279623          3.53305  3.48927    0.0437789          9879207
# 2014          282423          4.08514  4.01454    0.0705923         11537366
# 2015          286932           4.6328  4.55213    0.0806665       1.3293e+07
# 2016          293778          4.82623  4.71808      0.10815      1.41784e+07
# ...

# %%
df2.columns=['총1차에너지(천toe)','신·재생에너지 공급비중(%)','재생에너지(공급비중)','신에너지(공급비중)','신·재생에너지 합계(toe)','재생에너지','신에너지']

# %%
df2
# Out:
#         총1차에너지(천toe)  신·재생에너지 공급비중(%) 재생에너지(공급비중)   신에너지(공급비중)  \
# 에너지_종류  총1차에너지(천toe)  신·재생에너지 공급비중(%)       재생에너지         신에너지
# 2007          236678          2.36979     2.36902  0.000774047
# 2008          240994          2.43097     2.42915   0.00181208
# 2009          243500          2.49949      2.4916   0.00788214
# 2010          264053          2.59683     2.58079     0.016039
# 2011          276997          2.73752     2.71465    0.0228681
# 2012          278325             3.18     3.15036    0.0296452
# 2013          279623          3.53305     3.48927    0.0437789
# 2014          282423          4.08514     4.01454    0.0705923
# 2015          286932           4.6328     4.55213    0.0806665
# 2016          293778          4.82623     4.71808      0.10815
# 2017          302066          5.44529     5.25091     0.194383
# 2018          307501           5.8008     5.56053      0.24027
#
#         신·재생에너지 합계(toe)        재생에너지    신에너지
# ...

# %%
df2.drop('에너지_종류', inplace = True )

# %%
df2
# Out:
#      총1차에너지(천toe) 신·재생에너지 공급비중(%) 재생에너지(공급비중)   신에너지(공급비중) 신·재생에너지 합계(toe)  \
# 2007       236678         2.36979     2.36902  0.000774047         5608776
# 2008       240994         2.43097     2.42915   0.00181208         5858481
# 2009       243500         2.49949      2.4916   0.00788214         6086249
# 2010       264053         2.59683     2.58079     0.016039         6856284
# 2011       276997         2.73752     2.71465    0.0228681         7582845
# 2012       278325            3.18     3.15036    0.0296452         8850739
# 2013       279623         3.53305     3.48927    0.0437789         9879207
# 2014       282423         4.08514     4.01454    0.0705923        11537366
# 2015       286932          4.6328     4.55213    0.0806665      1.3293e+07
# 2016       293778         4.82623     4.71808      0.10815     1.41784e+07
# 2017       302066         5.44529     5.25091     0.194383     1.64484e+07
# ...

# %% [markdown]
# - 결측치 처리, 전처리를 완료한 데이터프레임 완성

# %% [markdown]
# #### 데이터프레임 정보

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2007 to 2018
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   총1차에너지(천toe)     12 non-null     object
#  1   신·재생에너지 공급비중(%)  12 non-null     object
#  2   재생에너지(공급비중)      12 non-null     object
#  3   신에너지(공급비중)       12 non-null     object
#  4   신·재생에너지 합계(toe)  12 non-null     object
#  5   재생에너지            12 non-null     object
#  6   신에너지             12 non-null     object
# dtypes: object(7)
# memory usage: 768.0+ bytes

# %% [markdown]
# #### 시각화 그래프 만들기

# %%
df3 = df2.drop(['총1차에너지(천toe)', '신·재생에너지 합계(toe)', '재생에너지', '신에너지' ], axis = 1)

# %%
df3
# Out:
#      신·재생에너지 공급비중(%) 재생에너지(공급비중)   신에너지(공급비중)
# 2007         2.36979     2.36902  0.000774047
# 2008         2.43097     2.42915   0.00181208
# 2009         2.49949      2.4916   0.00788214
# 2010         2.59683     2.58079     0.016039
# 2011         2.73752     2.71465    0.0228681
# 2012            3.18     3.15036    0.0296452
# 2013         3.53305     3.48927    0.0437789
# 2014         4.08514     4.01454    0.0705923
# 2015          4.6328     4.55213    0.0806665
# 2016         4.82623     4.71808      0.10815
# 2017         5.44529     5.25091     0.194383
# 2018          5.8008     5.56053      0.24027

# %% [markdown]
# - 재생에너지와 신에너지의 공급비중에 대해서만 정리하여 시각화 그래프 만들기

# %%
df3.to_csv('연도별 신.재생에너지 공급비중(%).csv')

# %%
df3.plot(figsize = (15, 9), marker = 'o')

# %% [markdown]
# - 신·재생에너지 공급비중에는 전체 합계에서 재생에너지가 대부분을 차지하고 신에너지는 아직 공급비중이 현저히 낮다는 것을 확인 할 수 있다.
#
#
# - 재생에너지의 공급비중은 11년 이후로 지속적으로 크게 증가중이다.

# %%
df4 = df2.drop(['총1차에너지(천toe)', '신·재생에너지 공급비중(%)', '재생에너지(공급비중)', '신에너지(공급비중)'], axis = 1 )

# %%
df4
# Out:
#      신·재생에너지 합계(toe)        재생에너지    신에너지
# 2007         5608776      5606944    1832
# 2008         5858481      5854113    4367
# 2009         6086249      6067056   19193
# 2010         6856284      6813938   42347
# 2011         7582845      7519502   63344
# 2012         8850739      8768229   82510
# 2013         9879207      9756791  122416
# 2014        11537366     11337997  199369
# 2015      1.3293e+07  1.30615e+07  231458
# 2016     1.41784e+07  1.38607e+07  317720
# 2017     1.64484e+07  1.58612e+07  587164
# 2018     1.78375e+07  1.70987e+07  738831

# %% [markdown]
# - 재생에너지와 신에너지의 공급비중에 대해서만 정리하여 시각화 그래프 만들기

# %%
df4.to_csv('연도별 신.재생에너지 생산량.csv')

# %%
df4.plot(figsize = (15, 9), marker = 'o')

# %% [markdown]
# - 신·재생에너지 생산량에는 전체 합계에서 재생에너지가 대부분을 차지하고 신에너지는 아직 에너지생산량이 현저히 낮다는 것을 확인 할 수 있다.
#
#
# - 신.재생에너지의 생산량도 11녀 이후로 지속적으로 증가하는 추세

# %%
df5 = df2.drop(['신·재생에너지 공급비중(%)','재생에너지(공급비중)','신에너지(공급비중)','신·재생에너지 합계(toe)', '재생에너지', '신에너지'], axis = 1)

# %%
df5
# Out:
#      총1차에너지(천toe)
# 2007       236678
# 2008       240994
# 2009       243500
# 2010       264053
# 2011       276997
# 2012       278325
# 2013       279623
# 2014       282423
# 2015       286932
# 2016       293778
# 2017       302066
# 2018       307501

# %% [markdown]
# - 신에너지, 재생에너지를 뺀 석유, 석탄, 원자력 등의 에너지의 총 합

# %%
df5.to_csv('총1차에너지.csv')

# %%
df5.plot(figsize = (15, 9), marker = 'o')

# %% [markdown]
# - 신에너지, 재생에너지를 뺀 에너지들의 생산량 촙 합은 2017년 까지 꾸준히 증가하는 추세이다
#
#
# - 11년까지 총 1차에너지의 생산량이 크게 증가하였다가 11년 이후로는 완만한 곡선으로 증가하고 있다.

# %% [markdown]
# #### 총 에너지 생산량에 관한 기술 통계

# %%
df6 = df2.astype('int')

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 2007 to 2018
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   총1차에너지(천toe)     12 non-null     int32
#  1   신·재생에너지 공급비중(%)  12 non-null     int32
#  2   재생에너지(공급비중)      12 non-null     int32
#  3   신에너지(공급비중)       12 non-null     int32
#  4   신·재생에너지 합계(toe)  12 non-null     int32
#  5   재생에너지            12 non-null     int32
#  6   신에너지             12 non-null     int32
# dtypes: int32(7)
# memory usage: 432.0+ bytes

# %%
df6.describe()
# Out:
#         총1차에너지(천toe)  신·재생에너지 공급비중(%)  재생에너지(공급비중)  신에너지(공급비중)  \
# count      12.000000        12.000000    12.000000        12.0
# mean   274405.833333         3.166667     3.166667         0.0
# std     23564.650100         1.193416     1.193416         0.0
# min    236678.000000         2.000000     2.000000         0.0
# 25%    258914.750000         2.000000     2.000000         0.0
# 50%    278974.000000         3.000000     3.000000         0.0
# 75%    288643.500000         4.000000     4.000000         0.0
# max    307501.000000         5.000000     5.000000         0.0
#
#        신·재생에너지 합계(toe)         재생에너지           신에너지
# count     1.200000e+01  1.200000e+01      12.000000
# mean      1.033477e+07  1.013389e+07  200879.250000
# std       4.276182e+06  4.050069e+06  239062.570904
# min       5.608776e+06  5.606944e+06    1832.000000
# 25%       6.663775e+06  6.627218e+06   36558.500000
# 50%       9.364973e+06  9.262510e+06  102463.000000
# ...

# %% [markdown]
# - 각 변수에 대한 기본통계

# %%
dfd = df6.describe()

# %%
dfd.to_csv('연도별 신.재생에너지, 총1차에너지, 공급비중 기본통계.csv')

# %% [markdown]
# ## 4. 2015 지역별 신.재생에너지 총 생산량

# %%
tf = pd.read_excel( '2015년 신재생에너지 보급통계(2016년판-초본).xls', sheet_name = '2.1 에너지생산량(지역별)' )

# %%
tf1 = tf.loc[3:7]

# %%
tf1
# Out:
#   2. 2015년 지역별 신·재생에너지 현황       Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 3                     NaN              구 분        NaN           전국         서울
# 4                     NaN              NaN        NaN        Total      Seoul
# 5                     NaN  신·재생에너지 합계(toe)        NaN   1.3293e+07     335295
# 6                     NaN              NaN      재생에너지  1.30615e+07     298327
# 7                     NaN              NaN       신에너지       231458      36968
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14  \
# 3         부산         대구         인천         광주         대전  ...          충북
# 4      Busan      Daegu    Incheon    Gwangju    Daejeon  ...    Chungbuk
# 5     145573     182528     628329    67587.7    65131.7  ...      318638
# 6     140255     172802     609804    67065.7    65087.7  ...      318634
# 7       5318       9726      18525        522         44  ...           4
#
# ...

# %% [markdown]
# #### 데이터 전처리 하기

# %%
tf1.iloc[0,0] = '구분'
tf1.iloc[2,0] = '신·재생에너지 합계(toe)'
tf1.iloc[3,0] = '재생에너지'
tf1.iloc[4,0] = '신에너지'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
tf1
# Out:
#   2. 2015년 지역별 신·재생에너지 현황       Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 3                      구분              구 분        NaN           전국         서울
# 4                     NaN              NaN        NaN        Total      Seoul
# 5         신·재생에너지 합계(toe)  신·재생에너지 합계(toe)        NaN   1.3293e+07     335295
# 6                   재생에너지              NaN      재생에너지  1.30615e+07     298327
# 7                    신에너지              NaN       신에너지       231458      36968
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14  \
# 3         부산         대구         인천         광주         대전  ...          충북
# 4      Busan      Daegu    Incheon    Gwangju    Daejeon  ...    Chungbuk
# 5     145573     182528     628329    67587.7    65131.7  ...      318638
# 6     140255     172802     609804    67065.7    65087.7  ...      318634
# 7       5318       9726      18525        522         44  ...           4
#
# ...

# %%
tf1.drop(['Unnamed: 1','Unnamed: 2','Unnamed: 21','Unnamed: 22','Unnamed: 23'],
          axis = 1, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
tf1
# Out:
#   2. 2015년 지역별 신·재생에너지 현황   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3                      구분           전국         서울         부산         대구
# 4                     NaN        Total      Seoul      Busan      Daegu
# 5         신·재생에너지 합계(toe)   1.3293e+07     335295     145573     182528
# 6                   재생에너지  1.30615e+07     298327     140255     172802
# 7                    신에너지       231458      36968       5318       9726
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 3         인천         광주         대전          울산          세종           경기
# 4    Incheon    Gwangju    Daejeon       Ulsan      Sejong     Gyeonggi
# 5     628329    67587.7    65131.7      694170     57878.8  1.40959e+06
# 6     609804    67065.7    65087.7      689306     57878.8  1.28159e+06
# 7      18525        522         44        4864           0       128009
#
#    Unnamed: 13 Unnamed: 14  Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# ...

# %%
tf1.drop(4)
# Out:
#   2. 2015년 지역별 신·재생에너지 현황   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 3                      구분           전국         서울         부산         대구
# 5         신·재생에너지 합계(toe)   1.3293e+07     335295     145573     182528
# 6                   재생에너지  1.30615e+07     298327     140255     172802
# 7                    신에너지       231458      36968       5318       9726
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  Unnamed: 12  \
# 3         인천         광주         대전          울산          세종           경기
# 5     628329    67587.7    65131.7      694170     57878.8  1.40959e+06
# 6     609804    67065.7    65087.7      689306     57878.8  1.28159e+06
# 7      18525        522         44        4864           0       128009
#
#    Unnamed: 13 Unnamed: 14  Unnamed: 15 Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 3           강원          충북           충남          전북           전남           경북
# 5   1.1058e+06      318638  1.70723e+06      555105  3.05316e+06  1.88861e+06
# ...

# %% [markdown]
# - 필요없는 행, 열 제거

# %%
tf1.columns=['구분','전국','서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북',
             '전남','경북','경남','제주']

# %% [markdown]
# - 열에 이름 부여하기

# %%
tf2 = tf1.drop([3,4])

# %%
tf2
# Out:
#                 구분           전국      서울      부산      대구      인천       광주  \
# 5  신·재생에너지 합계(toe)   1.3293e+07  335295  145573  182528  628329  67587.7
# 6            재생에너지  1.30615e+07  298327  140255  172802  609804  67065.7
# 7             신에너지       231458   36968    5318    9726   18525      522
#
#         대전      울산       세종           경기           강원      충북           충남  \
# 5  65131.7  694170  57878.8  1.40959e+06   1.1058e+06  318638  1.70723e+06
# 6  65087.7  689306  57878.8  1.28159e+06  1.10576e+06  318634  1.70124e+06
# 7       44    4864        0       128009           44       4         5995
#
#        전북           전남           경북      경남      제주
# 5  555105  3.05316e+06  1.88861e+06  710934  367423
# 6  552574  3.03768e+06   1.8852e+06  710920  367423
# 7    2531        15483         3411      14       0

# %% [markdown]
# - 전처리 완료

# %% [markdown]
# #### 2015 지역별 신.재생에너지 총 생산량 기본통계

# %% [markdown]
# - 기본통계 내기 위해 전처리

# %%
tf10 = tf2.T

# %%
tf10.columns=['신·재생에너지 합계(toe)','재생에너지','신에너지']

# %%
tf10.drop('구분', inplace = True)

# %%
tf10
# Out:
#    신·재생에너지 합계(toe)        재생에너지    신에너지
# 전국      1.3293e+07  1.30615e+07  231458
# 서울          335295       298327   36968
# 부산          145573       140255    5318
# 대구          182528       172802    9726
# 인천          628329       609804   18525
# 광주         67587.7      67065.7     522
# 대전         65131.7      65087.7      44
# 울산          694170       689306    4864
# 세종         57878.8      57878.8       0
# 경기     1.40959e+06  1.28159e+06  128009
# 강원      1.1058e+06  1.10576e+06      44
# 충북          318638       318634       4
# 충남     1.70723e+06  1.70124e+06    5995
# 전북          555105       552574    2531
# 전남     3.05316e+06  3.03768e+06   15483
# 경북     1.88861e+06   1.8852e+06    3411
# 경남          710934       710920      14
# 제주          367423       367423       0

# %% [markdown]
# - 재생에너지, 신에너지, 신.재생에너지 합계를 열로 바꿈

# %%
tf11 = tf10.astype('int')

# %%
tf11
# Out:
#     신·재생에너지 합계(toe)     재생에너지    신에너지
# 전국         13292990  13061532  231458
# 서울           335295    298327   36968
# 부산           145572    140254    5318
# 대구           182528    172802    9726
# 인천           628328    609803   18525
# 광주            67587     67065     522
# 대전            65131     65087      44
# 울산           694169    689305    4864
# 세종            57878     57878       0
# 경기          1409594   1281585  128009
# 강원          1105802   1105758      44
# 충북           318637    318633       4
# 충남          1707231   1701236    5995
# 전북           555104    552573    2531
# 전남          3053159   3037676   15483
# 경북          1888610   1885199    3411
# 경남           710934    710920      14
# 제주           367422    367422       0

# %%
tf11.drop('전국', inplace = True)

# %%
tf11
# Out:
#     신·재생에너지 합계(toe)    재생에너지    신에너지
# 서울           335295   298327   36968
# 부산           145572   140254    5318
# 대구           182528   172802    9726
# 인천           628328   609803   18525
# 광주            67587    67065     522
# 대전            65131    65087      44
# 울산           694169   689305    4864
# 세종            57878    57878       0
# 경기          1409594  1281585  128009
# 강원          1105802  1105758      44
# 충북           318637   318633       4
# 충남          1707231  1701236    5995
# 전북           555104   552573    2531
# 전남          3053159  3037676   15483
# 경북          1888610  1885199    3411
# 경남           710934   710920      14
# 제주           367422   367422       0

# %% [markdown]
# - 정수로 변환 후 전국 행 삭제

# %%
tf11.describe()
# Out:
#        신·재생에너지 합계(toe)         재생에너지           신에너지
# count     1.700000e+01  1.700000e+01      17.000000
# mean      7.819401e+05  7.683249e+05   13615.176471
# std       8.187092e+05  8.120271e+05   31009.360154
# min       5.787800e+04  5.787800e+04       0.000000
# 25%       1.825280e+05  1.728020e+05      44.000000
# 50%       5.551040e+05  5.525730e+05    3411.000000
# 75%       1.105802e+06  1.105758e+06    9726.000000
# max       3.053159e+06  3.037676e+06  128009.000000

# %% [markdown]
# - 각 지역별 재셍에너지, 신에너지, 두개의 합에 대한 기본통계

# %%
tftt = tf11.describe()

# %%
tftt.to_csv('2015년 신.재생에너지 총 생산량.csv')

# %% [markdown]
# #### 그래프로 나타내기 위해 전처리
# - 데이터프레임에서 숫자 항목만 따로 분리하여 정수로 타입 변환하기

# %%
tf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 5 to 7
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      3 non-null      object
#  1   전국      3 non-null      object
#  2   서울      3 non-null      object
#  3   부산      3 non-null      object
#  4   대구      3 non-null      object
#  5   인천      3 non-null      object
#  6   광주      3 non-null      object
#  7   대전      3 non-null      object
#  8   울산      3 non-null      object
#  9   세종      3 non-null      object
#  10  경기      3 non-null      object
#  11  강원      3 non-null      object
#  12  충북      3 non-null      object
#  13  충남      3 non-null      object
#  14  전북      3 non-null      object
#  15  전남      3 non-null      object
#  16  경북      3 non-null      object
#  17  경남      3 non-null      object
#  18  제주      3 non-null      object
# dtypes: object(19)
# memory usage: 480.0+ bytes

# %% [markdown]
# - 모든 항목이 오브젝트여서 그래프를 그리기 위해 정수로 변환해야 함

# %%
tf3 = tf2.drop('구분', axis = 1)

# %%
tf3
# Out:
#             전국      서울      부산      대구      인천       광주       대전      울산  \
# 5   1.3293e+07  335295  145573  182528  628329  67587.7  65131.7  694170
# 6  1.30615e+07  298327  140255  172802  609804  67065.7  65087.7  689306
# 7       231458   36968    5318    9726   18525      522       44    4864
#
#         세종           경기           강원      충북           충남      전북  \
# 5  57878.8  1.40959e+06   1.1058e+06  318638  1.70723e+06  555105
# 6  57878.8  1.28159e+06  1.10576e+06  318634  1.70124e+06  552574
# 7        0       128009           44       4         5995    2531
#
#             전남           경북      경남      제주
# 5  3.05316e+06  1.88861e+06  710934  367423
# 6  3.03768e+06   1.8852e+06  710920  367423
# 7        15483         3411      14       0

# %%
tf4 = tf2['구분']

# %%
tf4
# Out:
# 5    신·재생에너지 합계(toe)
# 6              재생에너지
# 7               신에너지
# Name: 구분, dtype: object

# %% [markdown]
# - 구분 항목과 전국 지역 항목을 분리

# %%
tf31 = tf3.astype('int')

# %%
tf31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 5 to 7
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전국      3 non-null      int32
#  1   서울      3 non-null      int32
#  2   부산      3 non-null      int32
#  3   대구      3 non-null      int32
#  4   인천      3 non-null      int32
#  5   광주      3 non-null      int32
#  6   대전      3 non-null      int32
#  7   울산      3 non-null      int32
#  8   세종      3 non-null      int32
#  9   경기      3 non-null      int32
#  10  강원      3 non-null      int32
#  11  충북      3 non-null      int32
#  12  충남      3 non-null      int32
#  13  전북      3 non-null      int32
#  14  전남      3 non-null      int32
#  15  경북      3 non-null      int32
#  16  경남      3 non-null      int32
#  17  제주      3 non-null      int32
# dtypes: int32(18)
# memory usage: 240.0 bytes

# %% [markdown]
# - 정수타입으로 변환

# %% [markdown]
# #### 행 인덱스로 그래프를 그리지 않고 전국, 즉 지역별로 그래프를 나타내기 위해 행 인덱스를 바꿔줌

# %%
tf6 = pd.concat([tf4, tf31], axis=1)
tf6
# Out:
#                 구분        전국      서울      부산      대구      인천     광주     대전  \
# 5  신·재생에너지 합계(toe)  13292990  335295  145572  182528  628328  67587  65131
# 6            재생에너지  13061532  298327  140254  172802  609803  67065  65087
# 7             신에너지    231458   36968    5318    9726   18525    522     44
#
#        울산     세종       경기       강원      충북       충남      전북       전남       경북  \
# 5  694169  57878  1409594  1105802  318637  1707231  555104  3053159  1888610
# 6  689305  57878  1281585  1105758  318633  1701236  552573  3037676  1885199
# 7    4864      0   128009       44       4     5995    2531    15483     3411
#
#        경남      제주
# 5  710934  367422
# 6  710920  367422
# 7      14       0

# %%
tf6.index = [ '신·재생에너지 합계', '재생에너지', '신에너지' ]

# %%
tf6.drop('구분', axis = 1, inplace = True)

# %%
tf6
# Out:
#                   전국      서울      부산      대구      인천     광주     대전      울산  \
# 신·재생에너지 합계  13292990  335295  145572  182528  628328  67587  65131  694169
# 재생에너지       13061532  298327  140254  172802  609803  67065  65087  689305
# 신에너지          231458   36968    5318    9726   18525    522     44    4864
#
#                세종       경기       강원      충북       충남      전북       전남  \
# 신·재생에너지 합계  57878  1409594  1105802  318637  1707231  555104  3053159
# 재생에너지       57878  1281585  1105758  318633  1701236  552573  3037676
# 신에너지            0   128009       44       4     5995    2531    15483
#
#                  경북      경남      제주
# 신·재생에너지 합계  1888610  710934  367422
# 재생에너지       1885199  710920  367422
# 신에너지           3411      14       0

# %%
tf6.to_csv('2015년 신.재생에너지 생산량 비율.csv')

# %%
tf7 = tf6.drop('전국', axis = 1)

# %%
tf7.index = ['신재생에너지_합계','재생에너지','신에너지']

# %%
tf7.T
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 서울     335295   298327   36968
# 부산     145572   140254    5318
# 대구     182528   172802    9726
# 인천     628328   609803   18525
# 광주      67587    67065     522
# 대전      65131    65087      44
# 울산     694169   689305    4864
# 세종      57878    57878       0
# 경기    1409594  1281585  128009
# 강원    1105802  1105758      44
# 충북     318637   318633       4
# 충남    1707231  1701236    5995
# 전북     555104   552573    2531
# 전남    3053159  3037676   15483
# 경북    1888610  1885199    3411
# 경남     710934   710920      14
# 제주     367422   367422       0

# %%
tfT = tf7.T

# %%
tfT.to_csv('2015년 지역별 신.재생에너지 총 생산량.csv')

# %% [markdown]
# #### 막대그래프

# %%
plt.style.use( 'ggplot' ) 
tf7.T.plot( kind = 'bar', figsize = ( 20, 10 ), width = 0.7, color = [ 'orange', 'green', 'pink' ] )
plt.title( '2015년 지역별 신·재생에너지 생산량', size = 30 )
plt.ylabel( '생산량', size = 20 )
plt.xlabel( '신·재생에너지 합계', size = 20 )
plt.ylim( 0, 3100000 )
plt.legend( loc = 'best', fontsize = 15 )

plt.show()

# %% [markdown]
# - 각 지역에서 신에너지는 재생에너지에 비해 턱없이 낮거나 없는 수준, 그나마 서울, 경기, 충남의 신에너지 그래프 수치가 보이는 정도로 에너지 생산량이 있음
# - 신.재생에너지 합이 가장 큰 지역은 전남, 경북, 충남 순이고 상대적으로 대전, 광주, 세종은 낮은편에 속한다.

# %% [markdown]
# #### 파이그래프

# %% [markdown]
# - 2015년 지역별 신·재생에너지 생산량

# %%
tf8 = tf7.T

# %%
tf8
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 서울     335295   298327   36968
# 부산     145572   140254    5318
# 대구     182528   172802    9726
# 인천     628328   609803   18525
# 광주      67587    67065     522
# 대전      65131    65087      44
# 울산     694169   689305    4864
# 세종      57878    57878       0
# 경기    1409594  1281585  128009
# 강원    1105802  1105758      44
# 충북     318637   318633       4
# 충남    1707231  1701236    5995
# 전북     555104   552573    2531
# 전남    3053159  3037676   15483
# 경북    1888610  1885199    3411
# 경남     710934   710920      14
# 제주     367422   367422       0

# %%
plt.figure( figsize = ( 7, 7 ) ) # 너비 5, 높이 5 
plt.pie( tf8.신재생에너지_합계, labels = tf8.index, autopct = '%.1f%%', startangle = 90, counterclock = False )
plt.title( '2015년 지역별 신재생에너지 생산량', size = 20 )
# Out:
# Text(0.5, 1.0, '2015년 지역별 신재생에너지 생산량')

# %% [markdown]
# - 2015년 전국 기준 재생에너지와 신에너지 비율

# %%
tfp = tf6.drop(['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남',
                '전북','전남','경북','경남','제주'], axis = 1)

# %%
tfp.drop('신·재생에너지 합계', inplace = True)

# %%
tfp
# Out:
#              전국
# 재생에너지  13061532
# 신에너지     231458

# %%
tfp[ '전국' ].plot( kind = 'pie', 
                           figsize = ( 7, 7 ),
                           autopct = '%1.1f%%',
                           colors = [ 'chocolate', 'cadetblue' ] )

plt.title( '2015년 신.재생에너지 총 생산량', size = 20 )
plt.axis( 'equal' )    # 파이 차트의 비율을 같게 (원에 가깝게) 조정
plt.legend( labels = tfp.index, loc = 'upper right' )   # 범례 표시

plt.show()

# %% [markdown]
# ## 5. 2016년 지역별 신·재생에너지 총 생산량

# %%
af = pd.read_excel( '(통계표1) 2018년 신재생에너지 보급통계(2019년 공표)_연도별_지역별 현황_한국에너지공단.xlsx', sheet_name = '2.1.3 에너지생산량(지역별)_2016')

# %%
af1 = af.loc[3:7]
af1
# Out:
#     2.1 지역별 신·재생에너지 생산량       Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4  \
# 3                   구 분              NaN        NaN           전국         서울
# 4                   NaN              NaN        NaN        Total      Seoul
# 5                   NaN  신·재생에너지 합계(toe)        NaN  1.41784e+07     316806
# 6                   NaN              NaN      재생에너지  1.38607e+07     278669
# 7                   NaN              NaN       신에너지       317720    38136.7
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14  \
# 3         부산         대구         인천         광주         대전  ...          충북
# 4      Busan      Daegu    Incheon    Gwangju    Daejeon  ...    Chungbuk
# 5     135772     181857     469248      70215      86763  ...      568359
# 6     129365     170946     445399    69668.4    86698.1  ...      568332
# 7     6406.4    10911.1      23850     546.57    64.8661  ...     26.5361
#
# ...

# %% [markdown]
# #### 데이터 전처리하기

# %%
af1.iloc[0,0] = '구분'
af1.iloc[2,0] = '신·재생에너지 합계(toe)'
af1.iloc[3,0] = '재생에너지'
af1.iloc[4,0] = '신에너지'
af1.drop(['Unnamed: 1','Unnamed: 2','Unnamed: 21','Unnamed: 22','Unnamed: 23'],
          axis = 1, inplace = True)
af1.drop(4)
af1.columns=['구분','전국','서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북',
             '전남','경북','경남','제주']
af2 = af1.drop([3,4])
af2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# #### 기본통계 내기 위해 전처리 후 기본통계

# %%
af10 = af2.T
af10.columns=['신·재생에너지 합계(toe)','재생에너지','신에너지']
af10.drop('구분', inplace = True)
af10
af11 = af10.astype('int')
af11
af11.drop('전국', inplace = True)
af11
af11.describe()
# Out:
#        신·재생에너지 합계(toe)         재생에너지           신에너지
# count     1.700000e+01  1.700000e+01      17.000000
# mean      8.340234e+05  8.153342e+05   18688.882353
# std       8.371665e+05  8.239516e+05   34507.062067
# min       7.021400e+04  6.966800e+04       0.000000
# 25%       1.818570e+05  1.709450e+05      50.000000
# 50%       5.683580e+05  5.683320e+05    2396.000000
# 75%       1.176786e+06  1.172800e+06   23849.000000
# max       3.034387e+06  3.009489e+06  124763.000000

# %% [markdown]
# - 각 지역별 재셍에너지, 신에너지, 두개의 합에 대한 기본통계

# %%
aaf = af11.describe()

# %%
aaf.to_csv('2016년 신.재생에너지 기본통계.csv')

# %% [markdown]
# #### 그래프로 나타내기 위해 전처리

# %%
af3 = af2.drop('구분', axis = 1)
af4 = af2['구분']
af31 = af3.astype('int')
af6 = pd.concat([af4, af31], axis=1)
af6.index = [ '신·재생에너지 합계', '재생에너지', '신에너지' ]
af6.drop('구분', axis = 1, inplace = True)
af7 = af6.drop('전국', axis = 1)
af7.index = ['신재생에너지_합계','재생에너지','신에너지']
af7.T
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 서울     316805   278669   38136
# 부산     135771   129365    6406
# 대구     181857   170945   10911
# 인천     469248   445398   23849
# 광주      70214    69668     546
# 대전      86762    86698      64
# 울산    1176786  1172800    3986
# 세종      84701    84701       0
# 경기    1514250  1389487  124763
# 강원     902962   902919      42
# 충북     568358   568332      26
# 충남    1840830  1759599   81231
# 전북     658316   657907     408
# 전남    3034387  3009489   24897
# 경북    2043004  2040607    2396
# 경남     667175   667125      50
# 제주     426972   426972       0

# %%
af6.to_csv('2016년 신.재생에너지 생산량 비율.csv')

# %%
aff1 = af7.T

# %%
aff1.to_csv('2016년 신.재생에너지 생산량 합.csv')

# %% [markdown]
# #### 2016년 지역별 신·재생에너지 합계 시각화 그래프

# %%
# 막대그래프
plt.style.use( 'ggplot' ) 
af7.T.plot( kind = 'bar', figsize = ( 20, 10 ), width = 0.7, color = [ 'orange', 'green', 'pink' ] )
plt.title( '2016년 지역별 신·재생에너지 생산량', size = 30 )
plt.ylabel( '생산량', size = 20 )
plt.xlabel( '신·재생에너지 합계', size = 20 )
plt.ylim( 0, 3100000 )
plt.legend( loc = 'best', fontsize = 15 )

# %% [markdown]
# - 2016년 또한 각 지역에서 신에너지는 재생에너지에 비해 턱없이 낮거나 없는 수준, 그나마 서울, 경기, 충남의 신에너지 그래프 수치가 보이는 정도로 에너지 생산량이 있음
# - 신.재생에너지 합이 가장 큰 지역은 전남, 경북, 충남 순이고 상대적으로 대전, 광주, 세종은 낮은편에 속한다.

# %%
# 파이그래프
af8 = af7.T
plt.figure( figsize = ( 7,7 ) ) # 너비 5, 높이 5 
plt.pie( af8.신재생에너지_합계, labels = af8.index, autopct = '%.1f%%', startangle = 90, counterclock = False )
plt.title( '2016년 지역별 신재생에너지 생산량', size = 20 )
# Out:
# Text(0.5, 1.0, '2016년 지역별 신재생에너지 생산량')

# %%
afp = af6.drop(['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남',
                '전북','전남','경북','경남','제주'], axis = 1)
afp.drop('신·재생에너지 합계', inplace = True)
afp[ '전국' ].plot( kind = 'pie', 
                           figsize = ( 7, 7 ),
                           autopct = '%1.1f%%',
                           colors = [ 'chocolate', 'cadetblue' ] )

plt.title( '2016년 신.재생에너지 총 생산량', size = 20 )
plt.axis( 'equal' )    # 파이 차트의 비율을 같게 (원에 가깝게) 조정
plt.legend( labels = afp.index, loc = 'upper right' )   # 범례 표시

plt.show()

# %% [markdown]
# ## 6. 2017년 신.재생에너지 총 생산량

# %%
# 읽고 전처리
sf = pd.read_excel( '(통계표1) 2018년 신재생에너지 보급통계(2019년 공표)_연도별_지역별 현황_한국에너지공단.xlsx', sheet_name = '2.1.2 에너지생산량(지역별)_2017')
sf1 = sf.loc[3:7]
sf1
sf1.iloc[0,0] = '구분'
sf1.iloc[2,0] = '신·재생에너지 합계(toe)'
sf1.iloc[3,0] = '재생에너지'
sf1.iloc[4,0] = '신에너지'
sf1.drop(['Unnamed: 1','Unnamed: 2','Unnamed: 21','Unnamed: 22','Unnamed: 23'],
          axis = 1, inplace = True)
sf1.drop(4)
sf1.columns=['구분','전국','서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북',
             '전남','경북','경남','제주']
sf2 = sf1.drop([3,4])
# 기본통계 내기 위해 전처리
sf10 = sf2.T
sf10.columns=['신·재생에너지 합계(toe)','재생에너지','신에너지']
sf10.drop('구분', inplace = True)
sf10
sf11 = tf10.astype('int')
sf11
sf11.drop('전국', inplace = True)
sf11
sf11.describe()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %% [markdown]
# - 2017년 신.재생에너지 총 생산량 기본통계

# %%
ssf = sf11.describe()

# %%
ssf.to_csv('2017년 신.재생에너지 총 생산량 기본통계.csv ')

# %%
#### 그래프로 나타내기 위해 전처리
sf3 = sf2.drop('구분', axis = 1)
sf4 = sf2['구분']
sf31 = sf3.astype('int')
sf6 = pd.concat([sf4, sf31], axis=1)
sf6.index = [ '신·재생에너지 합계', '재생에너지', '신에너지' ]
sf6.drop('구분', axis = 1, inplace = True)
sf7 = sf6.drop('전국', axis = 1)
sf7.index = ['신재생에너지_합계','재생에너지','신에너지']
sf7.T
#### 시각화 그래프 막대
plt.style.use( 'ggplot' ) 
sf7.T.plot( kind = 'bar', figsize = ( 20, 10 ), width = 0.7, color = [ 'orange', 'green', 'pink' ] )
plt.title( '2017년 지역별 신·재생에너지 생산량', size = 30 )
plt.ylabel( '생산량', size = 20 )
plt.xlabel( '신·재생에너지 합계', size = 20 )
plt.ylim( 0, 3300000 )
plt.legend( loc = 'best', fontsize = 15 )
plt.show()

# %%
sf6.to_csv('2017년 신.재생에너지 생산량 비율.csv')

# %%
#### 시각화 그래프 파이
sf8 = sf7.T
plt.figure( figsize = ( 7, 7 ) ) # 너비 5, 높이 5 
plt.pie( sf8.신재생에너지_합계, labels = sf8.index, autopct = '%.1f%%', startangle = 90, counterclock = False )
plt.title( '2017년 지역별 재생에너지 생산량', size = 20 )
# Out:
# Text(0.5, 1.0, '2017년 지역별 재생에너지 생산량')

# %%
sf7.index = ['신재생에너지_합계', '재생에너지', '신에너지']
sf7.T
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 서울     350880   281191   69688
# 부산     237438   198505   38933
# 대구     179156   170257    8899
# 인천     387825   362573   25252
# 광주      73199    72652     546
# 대전     113836   113750      85
# 울산    1343420  1338988    4432
# 세종      65440    65440       0
# 경기    1634363  1501521  132841
# 강원    1237809  1237768      41
# 충북     806868   806806      61
# 충남    2231253  1951391  279861
# 전북    1158328  1158139     189
# 전남    3229555  3206708   22847
# 경북    2345137  2341743    3394
# 경남     679022   678933      88
# 제주     374842   374842       0

# %%
#### 년도별 신에너지 재생에너지 비율
sfp = sf6.drop(['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남',
                '전북','전남','경북','경남','제주'], axis = 1)
sfp.drop('신·재생에너지 합계', inplace = True)
sfp[ '전국' ].plot( kind = 'pie', 
                           figsize = ( 7, 7 ),
                           autopct = '%1.1f%%',
                           colors = [ 'chocolate', 'cadetblue' ] )

plt.title( '2017년 신.재생에너지 총 생산량', size = 20 )
plt.axis( 'equal' )    # 파이 차트의 비율을 같게 (원에 가깝게) 조정
plt.legend( labels = sfp.index, loc = 'upper right' )   # 범례 표시

plt.show()

# %% [markdown]
# ## 7. 2018년 신.재생에너지 총 생산량

# %%
# 읽고 전처리하기
wf = pd.read_excel( '(통계표1) 2018년 신재생에너지 보급통계(2019년 공표)_연도별_지역별 현황_한국에너지공단.xlsx', sheet_name = '2.1.1 에너지생산량(지역별)_2018')
wf1 = wf.loc[3:9]
wf1.iloc[4,0] = '신·재생에너지 합계(toe)'
wf1.iloc[5,0] = '재생에너지'
wf1.iloc[6,0] = '신에너지'
wf1.drop(['Unnamed: 1','Unnamed: 2','Unnamed: 21','Unnamed: 22','Unnamed: 23'],
          axis = 1, inplace = True)
wf1.drop([3,4,6], inplace = True)
wf1.columns=['구분','전국','서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북',
             '전남','경북','경남','제주']

# 2018년 지역별 신재생에너지 현황 기본통계(전처리)
wf10 = wf1.T
wf10.drop('구분', inplace = True)
wf10.drop(5, axis = 1, inplace = True)
wf10.columns=['신·재생에너지 합계(toe)','재생에너지','신에너지']
wf11 = wf10.astype('int')
wf11
wf11.drop('전국', inplace = True)
wf11
wf11.describe()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
wwwf = wf11.describe()

# %%
wwwf.to_csv('2018년 지역별 신.재생에너지 총 생산량 기봉통계.csv')

# %% [markdown]
# #### 시각화 그래프 전 전처리

# %%
wf2 = wf1.drop(5)
wf3 = wf2.drop('구분', axis = 1)
wf4 = wf2['구분']
wf31 = wf3.astype('int')
wf6 = pd.concat([wf4, wf31], axis=1)
wf6.index = [ '신·재생에너지 합계', '재생에너지', '신에너지' ]
wf6.drop('구분', axis = 1, inplace = True)
wf7 = wf6.drop('전국', axis = 1)
wf7.index = ['신재생에너지_합계','재생에너지','신에너지']
wf7.T
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 서울     381545   313114   68431
# 부산     259304   203601   55702
# 대구     189913   181005    8908
# 인천     412625   368351   44273
# 광주      79351    78804     547
# 대전     132408   132313      95
# 울산    1030337  1026750    3587
# 세종      76201    76198       3
# 경기    1821078  1670146  150931
# 강원    1386743  1386660      83
# 충북     859703   859631      72
# 충남    2493271  2116419  376851
# 전북    1531690  1530831     859
# 전남    3439727  3413708   26019
# 경북    2524273  2521943    2329
# 경남     753622   753488     134
# 제주     465707   465707       0

# %%
wf6.to_csv('2018년 신.재생에너지 생산량 비율.csv')

# %%
wwff = wf7.T

# %%
wwff.to_csv('2018년 신.재생에너지 생산량 합.csv')

# %% [markdown]
# #### 막대그래프

# %%
plt.style.use( 'ggplot' ) 
wf7.T.plot( kind = 'bar', figsize = ( 20, 10 ), width = 0.7, color = [ 'orange', 'green', 'pink' ] )
plt.title( '2018년 지역별 신·재생에너지 생산량', size = 30 )
plt.ylabel( '생산량', size = 20 )
plt.xlabel( '신·재생에너지 합계', size = 20 )
plt.ylim( 0, 3100000 )
plt.legend( loc = 'best', fontsize = 15 )
plt.show()

# %% [markdown]
# #### 지역별 파이그래프

# %%
wf8 = wf7.T
plt.figure( figsize = ( 7, 7 ) ) # 너비 5, 높이 5 
plt.pie( wf8.신재생에너지_합계, labels = wf8.index, autopct = '%.1f%%', startangle = 90, counterclock = False )
plt.title( '2018년 지역별 재생에너지 생산량', size = 20 )
# Out:
# Text(0.5, 1.0, '2018년 지역별 재생에너지 생산량')

# %% [markdown]
# #### 2018년 신재생에너지 총 생산량 파이그래프

# %%
wfp = wf6.drop(['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남',
                '전북','전남','경북','경남','제주'], axis = 1)
wfp.drop('신·재생에너지 합계', inplace = True)
wfp[ '전국' ].plot( kind = 'pie', 
                           figsize = ( 7, 5 ),
                           autopct = '%1.1f%%',
                           colors = [ 'chocolate', 'cadetblue' ] )

plt.title( '2018년 신.재생에너지 총 생산량', size = 20 )
plt.axis( 'equal' )    # 파이 차트의 비율을 같게 (원에 가깝게) 조정
plt.legend( labels = wfp.index, loc = 'upper right' )   # 범례 표시

plt.show()

# %% [markdown]
# ## 8. 연도별 신.재생에너지 총 생산량 그래프 정리

# %% [markdown]
# ### 2015년

# %%
fig = plt.figure( figsize = ( 20, 10 ) )   
ax1 = fig.add_subplot( 1, 2, 1 )
ax2 = fig.add_subplot( 1, 2, 2 )
width = 0.35
labels = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
       '전북', '전남', '경북', '경남', '제주']
x= np.arange(len(labels))
ax1.bar( x -width/3 , tf7.T.신재생에너지_합계,width, color = 'orange', label = '신.재생에너지 총합')
ax1.bar( x +width/3 , tf7.T.재생에너지,width, color = 'skyblue',label = '재생에너지')
ax1.bar( x +2*width/3 , tf7.T.신에너지,width, color = 'green',label = '신에너지')
ax2.pie(tf8.신재생에너지_합계,labels = tf8.index, autopct = '%.1f%%', startangle = 90, counterclock = False)

ax1.set_xticks(x)
ax1.set_xticklabels(labels)
ax1.legend( loc = 'best' )

ax1.set_title('2015년 신.재생에너지 총 생산량',size=20)
ax2.set_title('2015년 신.재생에너지 총 생산량',size=20)
# Out:
# Text(0.5, 1.0, '2015년 신.재생에너지 총 생산량')

# %%
# 신.재생에너지_합계 TOP 5
tf7.T.sort_values(by='신재생에너지_합계' ,ascending=False).head()
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 전남    3053159  3037676   15483
# 경북    1888610  1885199    3411
# 충남    1707231  1701236    5995
# 경기    1409594  1281585  128009
# 강원    1105802  1105758      44

# %%
# 신.재생에너지_합계 BOTTOM 5
tf7.T.sort_values(by='신재생에너지_합계' ,ascending=True).head()
# Out:
#     신재생에너지_합계   재생에너지  신에너지
# 세종      57878   57878     0
# 대전      65131   65087    44
# 광주      67587   67065   522
# 부산     145572  140254  5318
# 대구     182528  172802  9726

# %% [markdown]
# -> 2015년 지역별 신재생에너지 생산량이 높은 지역은 (전남, 경북, 충남)이고 상대적으로 (세종, 대전, 광주)가 낮은 지역으로 확인됨
#
#
# -> 재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (경기, 서울, 전남) 순이다

# %% [markdown]
# ### 2016년

# %%
fig = plt.figure( figsize = ( 20, 10 ) )   
ax1 = fig.add_subplot( 1, 2, 1 )
ax2 = fig.add_subplot( 1, 2, 2 )
width = 0.35
labels = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
       '전북', '전남', '경북', '경남', '제주']
x= np.arange(len(labels))
ax1.bar( x -width/3 , af7.T.신재생에너지_합계,width, color = 'orange', label = '신.재생에너지 총합')
ax1.bar( x +width/3 , af7.T.재생에너지,width, color = 'skyblue',label = '재생에너지')
ax1.bar( x +2*width/3 , af7.T.신에너지,width, color = 'green',label = '신에너지')
ax2.pie(af8.신재생에너지_합계,labels = af8.index, autopct = '%.1f%%', startangle = 90, counterclock = False)

ax1.set_xticks(x)
ax1.set_xticklabels(labels)
ax1.legend( loc = 'best' )

ax1.set_title('2016년 신.재생에너지 총 생산량',size=20)
ax2.set_title('2016년 신.재생에너지 총 생산량',size=20)
# Out:
# Text(0.5, 1.0, '2016년 신.재생에너지 총 생산량')

# %%
# 신.재생에너지_합계 TOP 5
af7.T.sort_values(by='신재생에너지_합계' ,ascending=False).head()
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 전남    3034387  3009489   24897
# 경북    2043004  2040607    2396
# 충남    1840830  1759599   81231
# 경기    1514250  1389487  124763
# 울산    1176786  1172800    3986

# %%
# 신.재생에너지_합계 BOTTOM 5
af7.T.sort_values(by='신재생에너지_합계' ,ascending=True).head()
# Out:
#     신재생에너지_합계   재생에너지   신에너지
# 광주      70214   69668    546
# 세종      84701   84701      0
# 대전      86762   86698     64
# 부산     135771  129365   6406
# 대구     181857  170945  10911

# %% [markdown]
# -> 2016년 지역별 신재생에너지 생산량이 높은 지역은 16년과 같은(전남, 경북, 충남)이고 16년에 와서는 (광주, 세종, 대전)이 낮은 지역으로 확인됨
#
#
# -> 재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (경기, 충남, 서울) 순이다. 충남이 서울과 전남을 제침

# %% [markdown]
# ### 2017년

# %%
fig = plt.figure( figsize = ( 20, 10 ) )   
ax1 = fig.add_subplot( 1, 2, 1 )
ax2 = fig.add_subplot( 1, 2, 2 )
width = 0.35
labels = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
       '전북', '전남', '경북', '경남', '제주']
x= np.arange(len(labels))
ax1.bar( x -width/3 , sf7.T.신재생에너지_합계,width, color = 'orange', label = '신.재생에너지 총합')
ax1.bar( x +width/3 , sf7.T.재생에너지,width, color = 'skyblue',label = '재생에너지')
ax1.bar( x +2*width/3 , sf7.T.신에너지,width, color = 'green',label = '신에너지')
ax2.pie(sf8.신재생에너지_합계,labels = sf8.index, autopct = '%.1f%%', startangle = 90, counterclock = False)

ax1.set_xticks(x)
ax1.set_xticklabels(labels)
ax1.legend( loc = 'best' )

ax1.set_title('2017년 신.재생에너지 총 생산량',size=20)
ax2.set_title('2017년 신.재생에너지 총 생산량',size=20)
# Out:
# Text(0.5, 1.0, '2017년 신.재생에너지 총 생산량')

# %%
# 신.재생에너지_합계 TOP5
sf7.T.sort_values(by='신재생에너지_합계' ,ascending=False).head()
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 전남    3229555  3206708   22847
# 경북    2345137  2341743    3394
# 충남    2231253  1951391  279861
# 경기    1634363  1501521  132841
# 울산    1343420  1338988    4432

# %%
# 신.재생에너지_합계 BOTTOM 5
sf7.T.sort_values(by='신재생에너지_합계' ,ascending=True).head()
# Out:
#     신재생에너지_합계   재생에너지   신에너지
# 세종      65440   65440      0
# 광주      73199   72652    546
# 대전     113836  113750     85
# 대구     179156  170257   8899
# 부산     237438  198505  38933

# %% [markdown]
# -> 2017년 지역별 신재생에너지 생산량이 높은 지역은 작년과 같은(전남, 경북, 충남)이고 17년에 와서는 (세종, 광주, 대전)이 낮은 지역으로 확인됨
#
#
# -> 재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (충남, 경기, 서울) 순이다. 충남의 신에너지 생산량이 급격히 증가

# %% [markdown]
# ### 2018년

# %%
fig = plt.figure( figsize = ( 20, 10 ) )   
ax1 = fig.add_subplot( 1, 2, 1 )
ax2 = fig.add_subplot( 1, 2, 2 )
width = 0.35
labels = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
       '전북', '전남', '경북', '경남', '제주']
x= np.arange(len(labels))
ax1.bar( x -width/3 , wf7.T.신재생에너지_합계,width, color = 'orange', label = '신.재생에너지 총합')
ax1.bar( x +width/3 , wf7.T.재생에너지,width, color = 'skyblue',label = '재생에너지')
ax1.bar( x +2*width/3 , wf7.T.신에너지,width, color = 'green',label = '신에너지')
ax2.pie(wf8.신재생에너지_합계,labels = wf8.index, autopct = '%.1f%%', startangle = 90, counterclock = False)

ax1.set_xticks(x)
ax1.set_xticklabels(labels)
ax1.legend( loc = 'best' )

ax1.set_title('2018년 신.재생에너지 총 생산량',size=20)
ax2.set_title('2018년 신.재생에너지 총 생산량',size=20)
# Out:
# Text(0.5, 1.0, '2018년 신.재생에너지 총 생산량')

# %%
# 신.재생에너지_합계 TOP5
wf7.T.sort_values(by='신재생에너지_합계' ,ascending=False).head()
# Out:
#     신재생에너지_합계    재생에너지    신에너지
# 전남    3439727  3413708   26019
# 경북    2524273  2521943    2329
# 충남    2493271  2116419  376851
# 경기    1821078  1670146  150931
# 전북    1531690  1530831     859

# %%
# 신.재생에너지_합계 BOTTOM5
wf7.T.sort_values(by='신재생에너지_합계' ,ascending=True).head()
# Out:
#     신재생에너지_합계   재생에너지   신에너지
# 세종      76201   76198      3
# 광주      79351   78804    547
# 대전     132408  132313     95
# 대구     189913  181005   8908
# 부산     259304  203601  55702

# %% [markdown]
# -> 2018년 지역별 신재생에너지 생산량이 높은 지역은 작년과 같은(전남, 경북, 충남)이고 18년에 와서는 (세종, 광주, 대전)이 낮은 지역으로 확인됨
#
#
# -> 재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (충남, 경기, 서울) 순이다. 작년과 비교하여 변동 없음

# %% [markdown]
# ## 9. 연도별 신.재생에너지 총 생산량 비율

# %%
tft6 = tf6.drop(['신·재생에너지 합계'])
aft6 = af6.drop(['신·재생에너지 합계'])
sft6 = sf6.drop(['신·재생에너지 합계'])
wft6 = wf6.drop(['신·재생에너지 합계'])

# %%
fig = plt.figure( figsize = ( 20, 20) )   
ax1 = fig.add_subplot( 2, 2, 1 )
ax2 = fig.add_subplot( 2, 2, 2 )
ax3 = fig.add_subplot( 2, 2, 3 )
ax4 = fig.add_subplot( 2, 2, 4 )
width = 0.35
labels = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남',
       '전북', '전남', '경북', '경남', '제주']
x= np.arange(len(labels))
ax1.pie(tft6.전국,labels = tft6.index, autopct = '%.1f%%', startangle = 90, counterclock = False)
ax2.pie(aft6.전국,labels = aft6.index, autopct = '%.1f%%', startangle = 90, counterclock = False)
ax3.pie(sft6.전국,labels = sft6.index, autopct = '%.1f%%', startangle = 90, counterclock = False)
ax4.pie(wft6.전국,labels = wft6.index, autopct = '%.1f%%', startangle = 90, counterclock = False)



ax1.set_title('2015년 신.재생에너지 총 생산량',size=20)
ax2.set_title('2016년 신.재생에너지 총 생산량',size=20)
ax3.set_title('2017년 신.재생에너지 총 생산량',size=20)
ax4.set_title('2018년 신.재생에너지 총 생산량',size=20)
# Out:
# Text(0.5, 1.0, '2018년 신.재생에너지 총 생산량')

# %% [markdown]
# - 15년 ~ 18년, 4년의 기간동안 신.재생에너지 총합에서 신에너지의 비율이 1.7%에서 4.1%로 지속적으로 상승중이라는 것을 확인하였다.

# %% [markdown]
# ## 10. 신.재생에너지 총 발전량

# %%
from scipy import stats
import statsmodels.formula.api as smf
# %precision 3
# %matplotlib inline

# %%
ef = pd.read_excel( '(통계표1) 2018년 신재생에너지 보급통계(2019년 공표)_연도별_지역별 현황_한국에너지공단.xlsx' , sheet_name = '1.2 발전량')

# %%
ef1 = ef.iloc[1:19]

# %%
ef1
# Out:
#      1.2 연도별 신·재생에너지 발전량  Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 1                      구분        NaN        NaN        NaN         '07
# 2               총발전량(MWh)        NaN        NaN        NaN   426647338
# 3                     NaN       양수발전        NaN        NaN     1410813
# 4         신·재생에너지 공급비중(%)        NaN        NaN        NaN        1.03
# 5                     NaN      재생에너지        NaN        NaN     1.02809
# 6                     NaN       신에너지        NaN        NaN  0.00199743
# 7                     NaN        NaN        NaN        NaN
# 8       신·재생에너지 총발전량(MWh)        NaN        NaN        NaN     4394830
# 9                     NaN        NaN        NaN        사업용     4337232
# 10                    NaN        NaN        NaN        자가용       57598
# 11                    NaN        NaN        NaN        NaN         NaN
# 12                    NaN        NaN      재생에너지         합계     4386308
# ...

# %%
ef1.iloc[2,0] = '양수발전'
ef1.iloc[4,0] = '재생에너지'
ef1.iloc[5,0] = '신에너지'
ef1.iloc[8,0] = '사업용'
ef1.iloc[9,0] = '자가용'
ef1.iloc[11,0] = '재생에너지 합'
ef1.iloc[12,0] = '사업용'
ef1.iloc[13,0] = '자가용'
ef1.iloc[15,0] = '신에너지 합'
ef1.iloc[16,0] = '사업용'
ef1.iloc[17,0] = '자가용'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
ef1
# Out:
#      1.2 연도별 신·재생에너지 발전량  Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 1                      구분        NaN        NaN        NaN         '07
# 2               총발전량(MWh)        NaN        NaN        NaN   426647338
# 3                    양수발전       양수발전        NaN        NaN     1410813
# 4         신·재생에너지 공급비중(%)        NaN        NaN        NaN        1.03
# 5                   재생에너지      재생에너지        NaN        NaN     1.02809
# 6                    신에너지       신에너지        NaN        NaN  0.00199743
# 7                     NaN        NaN        NaN        NaN
# 8       신·재생에너지 총발전량(MWh)        NaN        NaN        NaN     4394830
# 9                     사업용        NaN        NaN        사업용     4337232
# 10                    자가용        NaN        NaN        자가용       57598
# 11                    NaN        NaN        NaN        NaN         NaN
# 12                재생에너지 합        NaN      재생에너지         합계     4386308
# ...

# %%
ef1.drop(['Unnamed: 1','Unnamed: 2','Unnamed: 3','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19'], axis = 1, inplace = True )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
ef1.columns=['에너지_종류','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']

# %%
ef1
# Out:
#                에너지_종류        2007        2008       2009       2010  \
# 1                  구분         '07         '08        '09        '10
# 2           총발전량(MWh)   426647338   422355126  433603745  474660205
# 3                양수발전     1410813     2492539    2827991    2789934
# 4     신·재생에너지 공급비중(%)        1.03           1       1.07       1.24
# 5               재생에너지     1.02809    0.996121    1.04441     1.1993
# 6                신에너지  0.00199743  0.00480875  0.0205879  0.0414949
# 7                 NaN
# 8   신·재생에너지 총발전량(MWh)     4394830     4227477    4617886    5889553
# 9                 사업용     4337232     4147211    4508680    5731501
# 10                자가용       57598       80266     109206     158052
# 11                NaN         NaN         NaN        NaN        NaN
# 12            재생에너지 합     4386308     4207167    4528616    5692594
# 13                사업용     4335272     4133779    4426921    5543430
# ...

# %%
ef2 = ef1.drop([7, 11, 15])

# %%
ef2.drop(1, inplace = True)

# %%
ef2
# Out:
#                에너지_종류        2007        2008       2009       2010  \
# 2           총발전량(MWh)   426647338   422355126  433603745  474660205
# 3                양수발전     1410813     2492539    2827991    2789934
# 4     신·재생에너지 공급비중(%)        1.03           1       1.07       1.24
# 5               재생에너지     1.02809    0.996121    1.04441     1.1993
# 6                신에너지  0.00199743  0.00480875  0.0205879  0.0414949
# 8   신·재생에너지 총발전량(MWh)     4394830     4227477    4617886    5889553
# 9                 사업용     4337232     4147211    4508680    5731501
# 10                자가용       57598       80266     109206     158052
# 12            재생에너지 합     4386308     4207167    4528616    5692594
# 13                사업용     4335272     4133779    4426921    5543430
# 14                자가용       51036       73388     101695     149164
# 16             신에너지 합        8522       20310      89270     196960
# 17                사업용        1960       13432      81759     188072
# ...

# %%
ef2.drop([2,3], inplace = True)

# %%
ef2
# Out:
#                에너지_종류        2007        2008       2009       2010  \
# 4     신·재생에너지 공급비중(%)        1.03           1       1.07       1.24
# 5               재생에너지     1.02809    0.996121    1.04441     1.1993
# 6                신에너지  0.00199743  0.00480875  0.0205879  0.0414949
# 8   신·재생에너지 총발전량(MWh)     4394830     4227477    4617886    5889553
# 9                 사업용     4337232     4147211    4508680    5731501
# 10                자가용       57598       80266     109206     158052
# 12            재생에너지 합     4386308     4207167    4528616    5692594
# 13                사업용     4335272     4133779    4426921    5543430
# 14                자가용       51036       73388     101695     149164
# 16             신에너지 합        8522       20310      89270     196960
# 17                사업용        1960       13432      81759     188072
# 18                자가용        6562        6878       7511       8888
#
#          2011       2012      2013      2014         2015         2016  \
# ...

# %%
ef3 = ef2.T

# %%
ef3
# Out:
#                      4         5           6                  8            9   \
# 에너지_종류  신·재생에너지 공급비중(%)     재생에너지        신에너지  신·재생에너지 총발전량(MWh)          사업용
# 2007               1.03   1.02809  0.00199743            4394830      4337232
# 2008                  1  0.996121  0.00480875            4227477      4147211
# 2009               1.07   1.04441   0.0205879            4617886      4508680
# 2010               1.24    1.1993   0.0414949            5889553      5731501
# 2011               3.46   3.39982   0.0587448           17345647     12712004
# 2012               3.66   3.59052   0.0732189           19498064     12768554
# 2013               3.95   3.84078    0.106533           21437822     15348683
# 2014               4.92   4.74859    0.172642           26882190     20910666
# 2015            6.60973   6.41448    0.195259        3.70789e+07   2.3829e+07
# 2016            7.23637   6.96866    0.267713        4.06558e+07  2.68062e+07
# ...

# %%
ef3.columns=['신재생에너지_공급비중','재생에너지','신에너지','신재생에너지_총발전량','사업용1','자가용1',
             '재생에너지 합','사업용2','자가용2','신에너지 합','사업용3','자가용3']

# %%
ef3.drop('에너지_종류', inplace = True)

# %%
ef3.columns = ['신재생에너지_공급비중','재생에너지','신에너지','신재생에너지_총발전량','사업용1','자가용1',
               '재생에너지 합','사업용2','자가용2','신에너지 합','사업용3','자가용3']

# %%
ef30 = ef3[['신재생에너지_공급비중','재생에너지','신에너지']]

# %%
ef40 = ef3[['신재생에너지_총발전량']]

# %%
ef50 = ef3[['재생에너지 합']]

# %%
ef60 = ef3[['신에너지 합']]

# %%
ef31 = ef30.astype('float')

# %%
ef41 = ef40.astype('int')

# %%
ef51 = ef50.astype('int')

# %%
ef61 = ef60.astype('int')

# %%
eff = pd.concat([ef31, ef41], axis=1)

# %%
eff
# Out:
#       신재생에너지_공급비중     재생에너지      신에너지  신재생에너지_총발전량
# 2007     1.030000  1.028088  0.001997      4394830
# 2008     1.000000  0.996121  0.004809      4227477
# 2009     1.070000  1.044413  0.020588      4617886
# 2010     1.240000  1.199299  0.041495      5889553
# 2011     3.460000  3.399822  0.058745     17345647
# 2012     3.660000  3.590517  0.073219     19498064
# 2013     3.950000  3.840785  0.106533     21437822
# 2014     4.920000  4.748592  0.172642     26882190
# 2015     6.609734  6.414476  0.195259     37078861
# 2016     7.236372  6.968659  0.267713     40655802
# 2017     8.075665  7.598465  0.477200     46623320
# 2018     8.880526  8.296509  0.584017     52718257

# %%
ef31.plot(figsize = (15, 9), marker = 'o')
]
# Out:
#   File "<ipython-input-350-034b0d5f18fa>", line 2
#     ]
#     ^
# SyntaxError: invalid syntax

# %%
ef41.plot(figsize = (15, 9), marker = 'o')

# %%
ef51.plot(figsize = (15, 9), marker = 'o', color = 'orange')

# %%
ef61.plot(figsize = (15, 9), marker = 'o', color = 'green')

# %% [markdown]
# ### x = 총발전량, y = 공급비중

# %%
x = np.array(eff['신재생에너지_총발전량'])
y = np.array(eff['신재생에너지_공급비중'])
p = 1

# %%
poly_fit = np.polyfit(x, y, 1)
poly_1d = np.poly1d(poly_fit)
xs = np.linspace(x.min(), x.max())
ys = poly_1d(xs)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.set_xlabel('신재생에너지_총발전량')
ax.set_ylabel('신재생에너지_공급비중')
ax.plot(xs, ys, color='blue', 
        label=f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x')
ax.scatter(x, y)
ax.legend()

plt.show()

# %%
# 반응변수 : final_test, 설명변수 : quiz
formula = '신재생에너지_공급비중 ~ 신재생에너지_총발전량'
result = smf.ols(formula, eff).fit()
result.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            신재생에너지_공급비중   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     5702.
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):           4.05e-15
# Time:                        15:18:48   Log-Likelihood:                 8.8265
# No. Observations:                  12   AIC:                            -13.65
# Df Residuals:                      10   BIC:                            -12.68
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ### x = 총공급량, y = 재생에너지

# %%
x = np.array(eff['신재생에너지_총발전량'])
y = np.array(eff['재생에너지'])
p = 1

# %%
poly_fit = np.polyfit(x, y, 1)
poly_1d = np.poly1d(poly_fit)
xs = np.linspace(x.min(), x.max())
ys = poly_1d(xs)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.set_xlabel('신재생에너지_총발전량')
ax.set_ylabel('재생에너지')
ax.plot(xs, ys, color='blue', 
        label=f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x')
ax.scatter(x, y)
ax.legend()

plt.show()

# %%
formula = '재생에너지 ~ 신재생에너지_총발전량'
result = smf.ols(formula, eff).fit()
result.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  재생에너지   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     2189.
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):           4.80e-13
# Time:                        15:18:48   Log-Likelihood:                 3.8367
# No. Observations:                  12   AIC:                            -3.673
# Df Residuals:                      10   BIC:                            -2.704
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ### x = 총공급량, y = 신에너지

# %%
x = np.array(eff['신재생에너지_총발전량'])
y = np.array(eff['신에너지'])
p = 1

# %%
poly_fit = np.polyfit(x, y, 1)
poly_1d = np.poly1d(poly_fit)
xs = np.linspace(x.min(), x.max())
ys = poly_1d(xs)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.set_xlabel('신재생에너지_총발전량')
ax.set_ylabel('신에너지')
ax.plot(xs, ys, color='blue', 
        label=f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x')
ax.scatter(x, y)
ax.legend()

plt.show()

# %%
formula = '신에너지 ~ 신재생에너지_총발전량'
result = smf.ols(formula, eff).fit()
result.summary()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   신에너지   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     66.53
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):           9.93e-06
# Time:                        15:18:49   Log-Likelihood:                 15.651
# No. Observations:                  12   AIC:                            -27.30
# Df Residuals:                      10   BIC:                            -26.33
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ## 11. EDA 결과

# %% [markdown]
# 1. 2015년 지역별 신재생에너지 생산량이 높은 지역은 (전남, 경북, 충남)이고 상대적으로 (세종, 대전, 광주)가 낮은 지역으로 확인됨,
#
#    재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (경기, 서울, 전남) 순이다
#
#
# 2. 2016년 지역별 신재생에너지 생산량이 높은 지역은 16년과 같은(전남, 경북, 충남)이고 16년에 와서는 (광주, 세종, 대전)이 낮은 지역으로 확인됨,
#
#    재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (경기, 충남, 서울) 순이다. 충남이 서울과 전남을 제침
#
#
# 3. 2017년 지역별 신재생에너지 생산량이 높은 지역은 작년과 같은(전남, 경북, 충남)이고 17년에 와서는 (세종, 광주, 대전)이 낮은 지역으로 확인됨,
#
#    재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (충남, 경기, 서울) 순이다. 충남의 신에너지 생산량이 급격히 증가
#
#
# 4. 2018년 지역별 신재생에너지 생산량이 높은 지역은 작년과 같은(전남, 경북, 충남)이고 18년에 와서는 (세종, 광주, 대전)이 낮은 지역으로 확인됨,
#
#    재생에너지는 신재생에너지 생산량의 추세와 비슷하고 신에너지 생산량은 (충남, 경기, 서울) 순이다. 작년과 비교하여 변동 없음
#
#
# 5. 1- 15년 ~ 18년, 4년의 기간동안 신.재생에너지 총합에서 신에너지의 비율이 1.7%에서 4.1%로 지속적으로 상승중이라는 것을 확인하였다.
